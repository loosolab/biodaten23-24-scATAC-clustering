# %% [markdown]
# # Submit zebrafish markers lists using the submit list notebook

# %% [markdown]
# This notebook allows you to create and upload a marker list. <br>
# <br>
# A marker list consists of two components: the metadata and the list(s) of markers. <br>
# The metadata is entered manually, while the markers are taken from a tab delimited file with one or two columns. <br>
# <br>
# In the settings you only have to specify the path to this marker file and information about the column(s) of the file <b>(2)</b>.
# <br>
# The submit lists notebook was modified to specifically process the format of the two zebrafish markers lists obtained from the scientific publication "Characterization of the Zebrafish Cell Landscape at Single-Cell Resolution".
# The lists are stored in two different Excel files: DataSheet1.XLSX and DataSheet2.XLSX. DataSheet1.XLSX contains the markers of the entire zebrafish cell landscape and the second file contains the markers of each tissue separately. The first code block was utilized to process the markers list from DataSheet1.XLSX, while second block was used for the second Excel file, as the files have distinct formats <b>(2.1)</b>. <br>
# <br>
# The input of the metadata as well as the verification and extension of the markers themselves, is supported by whitelists. The whitelists are located in an external repository, which is downloaded or updated before the data is entered <b>(3)</b>. <br>
# <br>
# Now the first metadata can be entered: the name of the list, the organism, and the type of markers (genes or genomic regions) <b>(4)</b>. <br>
# <br>
# At this point the marker file is being read in. If the markers are genes, they will be filtered and expanded using whitelists (Gene name and Ensembl ID) <b>(5)</b>. <br>
# <br>
# Finally, the remaining metadata can be entered and the new marker list can be saved <b>(6)</b>. <br>
# <br>
# The accuracy and integrity of the lists are confirmed through validation checks performed by the validation fuction <b>(7)</b>.

# %% [markdown]
# ## 1. Loading packages

# %%
import markerrepo.marker_repo as mr
import markerrepo.parsing as parse
import markerrepo.update_uids as u_uids
import markerrepo.generate_metafile as gm
import markerrepo.validate_yaml as validate
import markerrepo.utils as utils
import pandas as pd

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 2. Settings

# %% [markdown]
# Specify path of the cloned repository.

# %%
# The repo path must be specified as information entry 
# annotate_by_marker_and_features is the latest version of the repository

repo_path = "/mnt/workspace_stud/allstud/wp2/annotate_by_marker_and_features-sort"

# %% [markdown]
# The path of the list to be added to the marker repo. <br>
# The file must consist of one marker per line or two tab separated columns (marker and info like cell type).

# %% [markdown]
# ## 2.1 Submit zebrafish markers

# %%
# This code line reads the Excel file "DataSheet1.XLSX" into a pandas DataFrame named "df"
# It opens the sheet named "zebrafish cell landscape"
df = pd.read_excel(open("/mnt/workspace_stud/allstud/wp2/DataSheet1.XLSX", 'rb'), sheet_name="zebrafish cell landscape", index_col=[0])

# The code selects the columns that contain the string "gene name" from the DataFrame, it renames the columns using the first row 
# of the DataFrame and then drops the first row
cellGene = df.loc[:, df.columns.str.contains("gene name")].rename(columns=df.iloc[0]).drop(df.index[0])

# This empty list is used to store the marker information
# The first loop iterates over the column names with the cell types and the second loop iterates over the values in
# each column of the "cellGene"
# The variable "marker_info" creates a list containing the gene name and the cell type
# If the "marker_info" is not alreafy in the list, it will be added

marker_infos = []
for cellType in list(cellGene):
    for gene in cellGene[cellType]:
        marker_info = [gene, cellType]
        if marker_info not in marker_infos:
            marker_infos.append(marker_info)
            
# The variable "headers" defines the column headers for the DataFrame            
headers = ["Marker", "Info"]

# This line of code creates a new DataFrame named "markers"
markers = pd.DataFrame(marker_infos, columns=headers)

# The code returns the DataFrame "markers", which contains the marker information from the Excel file
markers
# Out:
#                  Marker                  Info
# 0             zgc:55461             Spermatid
# 1      si:ch73-111k22.3             Spermatid
# 2                tuba7l             Spermatid
# 3       si:dkey-40g16.5             Spermatid
# 4                 syce2             Spermatid
# ...                 ...                   ...
# 29009           atp5meb  Embryonic macrophage
# 29010            ndufb7  Embryonic macrophage
# 29011           cox7a2a  Embryonic macrophage
# 29012             cnbpb  Embryonic macrophage
# 29013            ATP5MD  Embryonic macrophage
#
# [29014 rows x 2 columns]

# %%
# The zebrafish markers are located in an Excel file named "DataSheet2.XLSX"
# The following code was designed specifically for the excel format containing the markers
# The code must be adjusted in case of using a new list with a different format

# This line reads the Excel file named "DataSheet2.XLSX" located at the specified path into a pandas DataFrame
# It reads the sheet named "Gill" from the Excel file and sets "index_col" to "None"
# The variable "sheet_name" must be changed manually to access sheets containing the markers for the other tissues

df = pd.read_excel(open("/mnt/workspace_stud/allstud/wp2/DataSheet2.XLSX", 'rb'), sheet_name="Testis", index_col=None)

# This line specifies the column names for gene name and cell type in the DataFrame to create the marker list
gene_column_name = "gene"
cell_type_column_name = "cell type"

# The missing values in the "cell type" column on the DataFrame are filled using the "fillna()" method
# The missing values i the "cell type" column of the DataFrame will be filled with the last valid value in the column
df[cell_type_column_name] = df[cell_type_column_name].fillna(method='ffill')

# The code creates a new DataFrame called "cellGene" containing only the columns "gene" and "celltype"
# It drops any rows with missing values
cellGene = df[[gene_column_name, cell_type_column_name]].dropna(subset=[cell_type_column_name])

# Finally, we rename the columns of the DataFrame to "Marker" (gene) and "Info" (cell type)
cellGene.columns = ["Marker", "Info"]

# This line creates a new DataFrame named "markers"
markers = pd.DataFrame(cellGene)

# The resulting DataFrame "markers" is displayed, which contains gene names and the corresponding cell type information
markers
# Out:
#                Marker                Info
# 0    si:ch211-121a2.2           Spermatid
# 1           zgc:92249           Spermatid
# 2               cremb           Spermatid
# 3           zgc:92789           Spermatid
# 4          BX004999.1           Spermatid
# ..                ...                 ...
# 944            maco1b  Innate immune cell
# 945             rpl21  Innate immune cell
# 946   si:ch211-5k11.8  Innate immune cell
# 947            aldoaa  Innate immune cell
# 948              pgls  Innate immune cell
#
# [949 rows x 2 columns]

# %% [markdown]
# ## 3. Get whitelists

# %% [markdown]
# Pull whitelist repository and update if necessary.

# %%
mr.get_whitelists()
# Out:
# Initiating whitelist fetching...
# Directory ./metadata_whitelists already exists.
# Update is set to False. Skipping update.
# Whitelist fetching process completed.

# %% [markdown]
# ## 4. Get essential metadata

# %% [markdown]
# Enter essential metadata: Liste name, organism and marker type

# %%
# LIST_NAME = input("Please enter the name of the marker list: ")
LIST_NAME = "zebrafish_gene_cellType"
ORGANISM = mr.select(key="organism")
MARKER_TYPE = mr.select(key="marker_type")
# Out:
# Select organism
# 1:	human 9606
# 2:	mouse 10090
# 3:	zebrafish 7955
# 4:	rat 10114
# 5:	pig 9823
# 6:	medaka 8090
# 7:	chicken 9031
# 8:	drosophila 7215
# 9:	yeast 4932
# 3
# Selection: zebrafish 7955
#
# Select marker_type
# 1:	Genes
# 2:	Genomic regions
# 1
# Selection: Genes

# %% [markdown]
# Read genes whitelist in order to filter and extend marker genes

# %%
if MARKER_TYPE == "Genes":
    gene_dict = mr.get_gene_dict(ORGANISM)

# %% [markdown]
# ## 5. Transform marker list

# %% [markdown]
# <b>Read</b>, <b>filter</b>, <b>extend</b> and <b>convert</b> marker list in order to append it to the yaml file.

# %%
markers['Marker'] = markers['Marker'].str.upper()
print("All markers of provided list:")
display(markers)

if MARKER_TYPE == "Genes":
    markers_removed = markers[~markers['Marker'].isin(gene_dict.keys())]
    print("Removed markers:")
    display(markers_removed)
    markers_filtered = markers[markers['Marker'].isin(gene_dict.keys())]
    markers_extended = mr.update_markers(markers_filtered, gene_dict)
    print("Filtered and extended markers:")
    display(markers_extended)
    marker_dict = parse.dataframe_to_dict(markers_extended)
else:
    marker_dict = parse.dataframe_to_dict(markers)
    
marker_list = []
for name in marker_dict.keys():
    marker_list.append({'name': name, 'markers': marker_dict[name]})
# Out:
# All markers of provided list:
#                Marker                Info
# 0    SI:CH211-121A2.2           Spermatid
# 1           ZGC:92249           Spermatid
# 2               CREMB           Spermatid
# 3           ZGC:92789           Spermatid
# 4          BX004999.1           Spermatid
# ..                ...                 ...
# 944            MACO1B  Innate immune cell
# 945             RPL21  Innate immune cell
# 946   SI:CH211-5K11.8  Innate immune cell
# 947            ALDOAA  Innate immune cell
# 948              PGLS  Innate immune cell
#
# [949 rows x 2 columns]
# Removed markers:
#                Marker                Info
# 1           ZGC:92249           Spermatid
# 3           ZGC:92789           Spermatid
# 25             LRRC69           Spermatid
# 34        GB:EH456644           Spermatid
# 42   SI:CH211-57H10.1           Spermatid
# 58               H1F0           Spermatid
# 59              NUPL2           Spermatid
# 62   SI:DKEY-148F10.4           Spermatid
# 63    SI:DKEYP-46H3.1           Spermatid
# 68         ZGC:110130           Spermatid
# 73         ZGC:153142           Spermatid
# 80           FAM212AB           Spermatid
# 89     SI:CH73-52E5.1           Spermatid
# 100  SI:CH211-261C8.5           Spermatid
# 104    SI:DKEY-71B5.6           Spermatid
# 176            FAM46C           Spermatid
# 206        FP016205.1           Spermatid
# 308             RPL41        Spermatocyte
# 332        FO704736.1        Spermatocyte
# 380       NC-002333.7        Spermatocyte
# 424        FO704736.1       Spermatogonia
# 504    CABZ01080371.3       Spermatogonia
# 513            H2AFX1       Spermatogonia
# 535       NC-002333.7       Spermatogonia
# 559           TMEM14A       Spermatogonia
# 605             RPL41       Spermatogonia
# 609  SI:DKEYP-94H10.5       Spermatogonia
# 618         ZGC:92066       Spermatogonia
# 625            SMIM30       Spermatogonia
# 638    CABZ01098670.1       Spermatogonia
# 665  SI:CH211-132P1.3       Spermatogonia
# 743         ZGC:77517          Macrophage
# 746         ZGC:92066          Macrophage
# 820        ZGC:153317          Macrophage
# 893        FO704736.1         Leydig cell
# 909            SMIM30         Leydig cell
# 911   SI:DKEY-77G12.1  Innate immune cell
# 912  SI:DKEY-203A12.6  Innate immune cell
# 914  SI:DKEY-203A12.8  Innate immune cell
# 915            SPINK2  Innate immune cell
# 924  SI:DKEY-203A12.3  Innate immune cell
# Filtered and extended markers:
#                                   Marker                Info
# 0    SI:CH211-121A2.2 ENSDARG00000039682           Spermatid
# 2               CREMB ENSDARG00000102899           Spermatid
# 4          BX004999.1 ENSDARG00000096792           Spermatid
# 5             FAM166B ENSDARG00000100292           Spermatid
# 6               TEKT1 ENSDARG00000101331           Spermatid
# ..                                   ...                 ...
# 944            MACO1B ENSDARG00000012741  Innate immune cell
# 945             RPL21 ENSDARG00000010516  Innate immune cell
# 946   SI:CH211-5K11.8 ENSDARG00000079078  Innate immune cell
# 947            ALDOAA ENSDARG00000011665  Innate immune cell
# 948              PGLS ENSDARG00000021233  Innate immune cell
#
# [908 rows x 2 columns]

# %% [markdown]
# ## 6. Enter metadata

# %% [markdown]
# Enter general metadata, tags and add marker list(s) automatically.

# %%
UID = mr.get_uid()
file_name = f"{LIST_NAME}_{UID}.yaml"

list_path = gm.generate_file(UID, LIST_NAME, False, marker_list, ORGANISM, MARKER_TYPE, repo_path=repo_path)
# Out:
# ____________________________________________________________________________________________________
#
#                                               Metadata
# ____________________________________________________________________________________________________
#
# This part contains the metadata of the list.
#
#
# ----------------------------------------------------------------------------------------------------
#                                              Submitter
# ----------------------------------------------------------------------------------------------------
#
# The one who submitted the list to the repository.
#
#
# The name should be entered in the format 'Last name, First name'.
# name: Quintanilla, Marta
#
# Do you want to add any of the following optional keys? (1,...,1 or n)
# 1:  email  The email adress of the submitter.
# n
#
# Do you want to add any of the following optional keys? (1,...,4 or n)
# 1:  date              The date when the content of the list was
#                       published. Format dd.mm.yyyy.
# 2:  reference_genome  Genome version of markers. WARNING: this key is
#                       essential when working with genomic regions!
# 3:  source            The source of the list.
# 4:  tags              Tags which describe the list.
# 25.02.2024
# Invalid entry, try again:
# 1
#
# The date when the content of the list was published. Format dd.mm.yyyy.
# date: 25.02.2024
# ----------------------------------------------------------------------------------------------------
#                                               SUMMARY
# ----------------------------------------------------------------------------------------------------
#
#
#     id: 1708882982698910
#     list_name: zebrafish_gene_cellType
#     organism:
#         organism_name: zebrafish
#         taxonomy_id: 7955
#     marker_type: Genes
#     submitter:
#         name: Quintanilla, Marta
#     date: 25.02.2024
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
#                                               SUMMARY
# ----------------------------------------------------------------------------------------------------
#
#
#   - name: Spermatid
#     markers:
#       - SI:CH211-121A2.2 ENSDARG00000039682
#       - CREMB ENSDARG00000102899
#       - BX004999.1 ENSDARG00000096792
#       - FAM166B ENSDARG00000100292
#       - TEKT1 ENSDARG00000101331
#       - SI:CH211-242F23.3 ENSDARG00000095223
#       - CCDC103 ENSDARG00000053455
#       - DNALI1 ENSDARG00000069815
#       - FANK1 ENSDARG00000039657
#       - FAM183A ENSDARG00000087144
#       - CKBA ENSDARG00000069752
#       - TP53INP2 ENSDARG00000088178
#       - SI:CH211-147D7.5 ENSDARG00000095457
#       - SI:CH211-141O9.10 ENSDARG00000077900
#       - CFAP126 ENSDARG00000070868
#       - ODF3B ENSDARG00000042396
#       - CFAP77 ENSDARG00000068122
#       - SI:CH211-163L21.7 ENSDARG00000034457
#       - EPHX1 ENSDARG00000042854
#       - SI:DKEY-58J15.10 ENSDARG00000096515
#       - SI:DKEY-11C5.11 ENSDARG00000096637
#       - SI:CH211-110E21.3 ENSDARG00000089338
#       - SI:CH211-248E11.2 ENSDARG00000058940
#       - SI:DKEYP-81F3.4 ENSDARG00000105458
#       - UBE2H ENSDARG00000000019
#       - FBXO36B ENSDARG00000039152
#       - DEGS2 ENSDARG00000042544
#       - ROPN1L ENSDARG00000058370
#       - DNAI1.1 ENSDARG00000100081
#       - SI:DKEYP-50B9.1 ENSDARG00000097421
#       - CFAP52 ENSDARG00000101679
#       - PVALB6 ENSDARG00000009311
#       - PPM1BA ENSDARG00000001888
#       - ZGC:153665 ENSDARG00000043442
#       - SI:DKEY-43K4.3 ENSDARG00000052428
#       - TMEM218 ENSDARG00000027129
#       - FLJ11011L ENSDARG00000045360
#       - SI:CH211-209A2.2 ENSDARG00000093734
#       - TPD52 ENSDARG00000061713
#       - SI:DKEY-42P14.3 ENSDARG00000092825
#       - SI:CH73-111K22.3 ENSDARG00000103492
#       - SI:CH211-107E6.5 ENSDARG00000097573
#       - IFT81 ENSDARG00000007444
#       - MLF1 ENSDARG00000077301
#       - PACRG ENSDARG00000087556
#       - CFAP206 ENSDARG00000021997
#       - SI:DKEY-70B23.2 ENSDARG00000093783
#       - CATIP ENSDARG00000063009
#       - SPACA9 ENSDARG00000068130
#       - MIF4GDB ENSDARG00000102578
#       - LENG9 ENSDARG00000062374
#       - SI:DKEY-86L18.10 ENSDARG00000105528
#       - UBE2R2 ENSDARG00000058740
#       - IFT80 ENSDARG00000038879
#       - CART3 ENSDARG00000035852
#       - LRRC51 ENSDARG00000040668
#       - MAATS1 ENSDARG00000006292
#       - RAB36 ENSDARG00000014058
#       - MEIG1 ENSDARG00000045705
#       - BTBD16 ENSDARG00000027710
#       - NFATC2IP ENSDARG00000011360
#       - SI:DKEY-27P23.3 ENSDARG00000075714
#       - ENO4 ENSDARG00000070598
#       - NEK2 ENSDARG00000005619
#       - DNAI2A ENSDARG00000100285
#       - CFAP45 ENSDARG00000068103
#       - HHLA2A.1 ENSDARG00000043182
#       - SUMO1 ENSDARG00000044267
#       - IQCG ENSDARG00000068678
#       - ENKUR ENSDARG00000031248
#       - SI:CH211-122L24.6 ENSDARG00000112759
#       - CAPSLA ENSDARG00000103521
#       - SI:DKEY-111E8.4 ENSDARG00000093547
#       - CBY1 ENSDARG00000077409
#       - CFAP53 ENSDARG00000100892
#       - SAXO2 ENSDARG00000006474
#       - SINUP ENSDARG00000017163
#       - IQCD ENSDARG00000035551
#       - COQ9 ENSDARG00000023583
#       - CR382372.1 ENSDARG00000096684
#       - SRGN ENSDARG00000077069
#       - DCST2 ENSDARG00000088693
#       - USP2A ENSDARG00000020107
#       - AL928901.1 ENSDARG00000100960
#       - SI:CH211-284K5.2 ENSDARG00000101455
#       - CCDC166 ENSDARG00000101235
#       - BX284635.1 ENSDARG00000092456
#       - UBE2B ENSDARG00000026035
#       - C2CD2L ENSDARG00000061066
#       - FXYD6L ENSDARG00000097057
#       - DMC1 ENSDARG00000055883
#       - SI:DKEYP-110G5.4 ENSDARG00000092482
#       - IQUB ENSDARG00000061899
#       - PPP1R42 ENSDARG00000057632
#       - PPP6R2A ENSDARG00000045540
#       - RAG2 ENSDARG00000052121
#       - SI:CH211-226M16.3 ENSDARG00000026864
#       - TSNAXIP1 ENSDARG00000030512
#       - PRKAR1AB ENSDARG00000101755
#       - STYXL1 ENSDARG00000026338
#       - ZMYND12 ENSDARG00000017055
#       - CR847939.1 ENSDARG00000100639
#       - SI:CH211-69G19.2 ENSDARG00000070656
#       - ZGC:123244 ENSDARG00000056144
#       - DHRS9 ENSDARG00000019260
#       - FOXM1 ENSDARG00000003200
#       - SI:CH211-116O3.5 ENSDARG00000097692
#       - TEX9 ENSDARG00000010586
#       - SI:CH1073-82L19.1 ENSDARG00000101799
#       - SI:CH211-152P11.4 ENSDARG00000079705
#       - KCNN4 ENSDARG00000086091
#       - WBP2 ENSDARG00000056605
#       - BX640520.3 ENSDARG00000095363
#       - PREP ENSDARG00000057151
#       - TLR5A ENSDARG00000044415
#       - TTC23 ENSDARG00000022160
#       - NPTX2A ENSDARG00000037794
#       - FOSL1B ENSDARG00000079373
#       - POLB ENSDARG00000003749
#       - DNAAF3L ENSDARG00000036304
#       - SPAG8 ENSDARG00000103843
#       - SI:CH211-10A23.2 ENSDARG00000060656
#       - ZGC:172182 ENSDARG00000039824
#       - NUSAP1 ENSDARG00000002403
#       - BX539313.2 ENSDARG00000097454
#       - SI:CH211-272N13.3 ENSDARG00000099768
#       - UBE2J2 ENSDARG00000061161
#       - PHLDA2 ENSDARG00000042874
#       - SI:CH211-176L24.4 ENSDARG00000097203
#       - BX950187.1 ENSDARG00000095282
#       - WDR95 ENSDARG00000054572
#       - FAM221A ENSDARG00000027599
#       - SI:DKEY-77F5.4 ENSDARG00000097808
#       - ZGC:153215 ENSDARG00000055889
#       - CDKL1 ENSDARG00000017329
#       - NFE2L3 ENSDARG00000019810
#       - ZGC:194114 ENSDARG00000074950
#       - SI:CH73-141C7.1 ENSDARG00000009040
#       - SI:CH211-9N13.3 ENSDARG00000093432
#       - SI:CH211-63O20.7 ENSDARG00000042000
#       - SPINT1A ENSDARG00000102332
#       - TTC12 ENSDARG00000056896
#       - PNRC1 ENSDARG00000043904
#       - FAM219AA ENSDARG00000016396
#       - SI:CH211-151H10.2 ENSDARG00000068250
#       - PPCDC ENSDARG00000033020
#       - DNAJB2 ENSDARG00000058644
#       - BX890548.1 ENSDARG00000099355
#       - ATF7IP ENSDARG00000069619
#       - KNOP1 ENSDARG00000077721
#       - CCDC87 ENSDARG00000045683
#       - AGBL2 ENSDARG00000079983
#       - FIBPA ENSDARG00000016058
#       - CCNA1 ENSDARG00000043236
#       - SI:DKEY-57A22.11 ENSDARG00000092651
#       - TRAF3IP1 ENSDARG00000010300
#       - CR855277.2 ENSDARG00000092801
#       - ITCHA ENSDARG00000074903
#       - DZIP1L ENSDARG00000074265
#       - FXYD1 ENSDARG00000099014
#       - MSH5 ENSDARG00000077479
#       - HSBP1L1 ENSDARG00000075984
#       - CU657980.1 ENSDARG00000054846
#       - CFAP43 ENSDARG00000001825
#       - LO018541.1 ENSDARG00000107593
#       - BX005254.1 ENSDARG00000093797
#       - SAT1B ENSDARG00000032272
#       - TAC3A ENSDARG00000093089
#       - SI:CH211-271E10.1 ENSDARG00000095735
#       - FAAP24 ENSDARG00000051731
#       - KLHL26 ENSDARG00000053876
#       - CCDC88AA ENSDARG00000078440
#       - RAD9B ENSDARG00000075632
#       - KIF11 ENSDARG00000010948
#       - XRRA1 ENSDARG00000089578
#       - PIP5K1BB ENSDARG00000006508
#       - CERKL ENSDARG00000079397
#       - BX649411.2 ENSDARG00000105079
#       - EIF4G3A ENSDARG00000077215
#       - MUSTN1A ENSDARG00000054026
#       - HBBA1 ENSDARG00000097238
#       - CU468164.1 ENSDARG00000052609
#       - ZGC:194627 ENSDARG00000102594
#       - KLHL24A ENSDARG00000021739
#       - CSNK1G1 ENSDARG00000104342
#       - NCBP3 ENSDARG00000044597
#       - PHF23A ENSDARG00000030887
#       - SLC39A9 ENSDARG00000070447
#       - JOSD2 ENSDARG00000057626
#       - BX465227.1 ENSDARG00000097825
#       - KIF20A ENSDARG00000044491
#       - CCDC78 ENSDARG00000030095
#       - AK9 ENSDARG00000021913
#   - name: Spermatocyte
#     markers:
#       - NOP56 ENSDARG00000012820
#       - STMN1A ENSDARG00000004169
#       - SETB ENSDARG00000003920
#       - METAP2B ENSDARG00000102571
#       - TUBB2B ENSDARG00000098591
#       - PCNA ENSDARG00000054155
#       - HMGN2 ENSDARG00000099572
#       - DKC1 ENSDARG00000016484
#       - SUMO3B ENSDARG00000035993
#       - HP1BP3 ENSDARG00000044669
#       - NPM1A ENSDARG00000014329
#       - GSTR ENSDARG00000042620
#       - LSM7 ENSDARG00000058328
#       - SERBP1A ENSDARG00000074242
#       - TUBA8L4 ENSDARG00000006260
#       - NCL ENSDARG00000002710
#       - SI:CH73-281N10.2 ENSDARG00000097102
#       - DEK ENSDARG00000070108
#       - SI:CH211-156B7.4 ENSDARG00000101707
#       - RPLP2L ENSDARG00000011201
#       - RPS4X ENSDARG00000014690
#       - KHDRBS1A ENSDARG00000052856
#       - MCM4 ENSDARG00000040041
#       - FOSAB ENSDARG00000031683
#       - DAZL ENSDARG00000036214
#       - YWHAQA ENSDARG00000042539
#       - HSPE1 ENSDARG00000056167
#       - SI:CH211-288G17.3 ENSDARG00000070959
#       - BTF3L4 ENSDARG00000089681
#       - MCM3 ENSDARG00000024204
#       - ATP5F1C ENSDARG00000045514
#       - H3F3B.1 ENSDARG00000068434
#       - MIF ENSDARG00000071336
#       - MCM5 ENSDARG00000019507
#       - NOP58 ENSDARG00000104353
#       - GSTP1 ENSDARG00000104068
#       - RCC2 ENSDARG00000011510
#       - PPIAB ENSDARG00000103994
#       - RPL32 ENSDARG00000054818
#       - DNAJC9 ENSDARG00000031293
#       - MCM6 ENSDARG00000057683
#       - HNRNPABB ENSDARG00000099865
#       - PA2G4A ENSDARG00000039578
#       - ASF1BB ENSDARG00000043713
#       - CBX3A ENSDARG00000003860
#       - SMFN ENSDARG00000009806
#       - TXNDC17 ENSDARG00000058079
#       - MYL12.1 ENSDARG00000099766
#       - DDX4 ENSDARG00000014373
#       - BANF1 ENSDARG00000037009
#       - SI:CH211-226L4.6 ENSDARG00000105573
#       - EEF2B ENSDARG00000100371
#       - PPA1B ENSDARG00000030441
#       - ILF2 ENSDARG00000014591
#       - EIF3G ENSDARG00000016889
#       - SI:CH73-1A9.3 ENSDARG00000103919
#       - NIP7 ENSDARG00000059075
#       - DDX18 ENSDARG00000030789
#       - RPL18A ENSDARG00000025073
#       - FEN1 ENSDARG00000011404
#       - MGMT ENSDARG00000043275
#       - FBL ENSDARG00000053912
#       - RPL38 ENSDARG00000006413
#       - RPS5 ENSDARG00000043453
#       - MRPL54 ENSDARG00000071468
#       - POLR2K ENSDARG00000075616
#       - ADH5 ENSDARG00000080010
#       - COIL ENSDARG00000040070
#       - TIMM10 ENSDARG00000069116
#       - APEX1 ENSDARG00000045843
#       - CFL1 ENSDARG00000021124
#       - NASP ENSDARG00000039208
#       - ATP5IF1A ENSDARG00000067975
#       - ZGC:162025 ENSDARG00000046141
#       - HMGB2A ENSDARG00000029722
#       - RPS6 ENSDARG00000019778
#       - DUT ENSDARG00000106529
#       - CNBPB ENSDARG00000070922
#       - CDCA7A ENSDARG00000077620
#       - CCT5 ENSDARG00000045399
#       - HMGN6 ENSDARG00000087636
#       - LBR ENSDARG00000014013
#       - RPS25 ENSDARG00000041811
#       - GSTM.1 ENSDARG00000042533
#       - RPS26 ENSDARG00000037071
#       - CHTOPB ENSDARG00000070430
#       - SI:DKEY-239H2.3 ENSDARG00000092033
#       - MGST3B ENSDARG00000033364
#       - MRPL36 ENSDARG00000070607
#       - ADSSL ENSDARG00000012399
#       - RPL4 ENSDARG00000041182
#       - MRPS18A ENSDARG00000024465
#       - CIRBPA ENSDARG00000103672
#       - RBBP4 ENSDARG00000029058
#       - EIF3D ENSDARG00000021257
#       - RPL36A ENSDARG00000058105
#       - MRTO4 ENSDARG00000007130
#       - RACK1 ENSDARG00000041619
#       - RPS12 ENSDARG00000036875
#       - HDAC1 ENSDARG00000015427
#       - PDAP1A ENSDARG00000092546
#       - RPS21 ENSDARG00000025850
#       - PES ENSDARG00000018902
#       - RPL5B ENSDARG00000015862
#       - GAPDHS ENSDARG00000039914
#       - ATP5MC3B ENSDARG00000009447
#       - RPL36 ENSDARG00000100588
#       - SETA ENSDARG00000031495
#       - RPL23A ENSDARG00000006316
#       - RPL13A ENSDARG00000044093
#       - TRMT112 ENSDARG00000071878
#       - MIBP ENSDARG00000101362
#       - RRM1 ENSDARG00000014017
#       - ANP32B ENSDARG00000023330
#       - RPS28 ENSDARG00000035860
#       - SIVA1 ENSDARG00000114552
#       - CDC6 ENSDARG00000009942
#       - RPS11 ENSDARG00000053058
#       - HSPD1 ENSDARG00000056160
#       - PHO ENSDARG00000035133
#       - RPS27.2 ENSDARG00000055475
#       - NACA ENSDARG00000005513
#       - RPLP1 ENSDARG00000021864
#       - RSL1D1 ENSDARG00000055868
#       - RSL24D1 ENSDARG00000040439
#       - TOMM7 ENSDARG00000067717
#       - TARDBP ENSDARG00000040031
#       - RPL13 ENSDARG00000099380
#       - MCL1A ENSDARG00000009779
#       - GAR1 ENSDARG00000076526
#       - COX5AA ENSDARG00000088383
#       - PARK7 ENSDARG00000116835
#       - MARCKSB ENSDARG00000008803
#       - SI:ZFOS-169G10.3 ENSDARG00000099309
#       - RPL35A ENSDARG00000088030
#       - RPS18 ENSDARG00000100392
#       - COX14 ENSDARG00000092124
#       - SI:CH211-282B22.1 ENSDARG00000097630
#       - IMP3 ENSDARG00000115266
#       - HNRNPA0B ENSDARG00000036162
#       - RPS13 ENSDARG00000036298
#       - SI:DKEY-33C12.4 ENSDARG00000057890
#       - RNASEH2A ENSDARG00000018891
#       - RPS14 ENSDARG00000036629
#       - THYN1 ENSDARG00000042659
#       - NUCKS1B ENSDARG00000012777
#       - RPL7A ENSDARG00000019230
#       - ASF1BA ENSDARG00000101037
#       - PIWIL1 ENSDARG00000041699
#       - RPS3A ENSDARG00000035692
#       - RPL7 ENSDARG00000007320
#       - RPL3 ENSDARG00000003599
#       - EEF1DA ENSDARG00000102291
#       - RFC3 ENSDARG00000055969
#       - DBI ENSDARG00000026369
#       - ORG ENSDARG00000076474
#       - RPS15A ENSDARG00000010160
#       - MARCKSL1B ENSDARG00000035715
#       - DDB2 ENSDARG00000041140
#       - WDR12 ENSDARG00000003287
#       - HNRNPL2 ENSDARG00000059303
#       - MRPL43 ENSDARG00000076334
#       - RPS2 ENSDARG00000077291
#       - PDCD4A ENSDARG00000021702
#       - TOMM6 ENSDARG00000097797
#       - EBNA1BP2 ENSDARG00000054980
#       - MYCLA ENSDARG00000006003
#       - UBE2NB ENSDARG00000045877
#       - ARL6IP4 ENSDARG00000105036
#       - SI:DKEY-102M7.3 ENSDARG00000100366
#       - RPS3 ENSDARG00000103007
#       - RPL17 ENSDARG00000057556
#       - RPL29 ENSDARG00000077717
#       - EEF1A1L1 ENSDARG00000020850
#       - MCM2 ENSDARG00000102798
#       - HMGB2B ENSDARG00000053990
#       - SI:CH211-217K17.7 ENSDARG00000059908
#       - CDCA7B ENSDARG00000076659
#       - TCP1 ENSDARG00000017891
#   - name: Spermatogonia
#     markers:
#       - CR318588.4 ENSDARG00000095556
#       - COX6B1 ENSDARG00000045230
#       - NPM1A ENSDARG00000014329
#       - B2M ENSDARG00000053136
#       - EIF3G ENSDARG00000016889
#       - LSM7 ENSDARG00000058328
#       - SI:DKEY-102M7.3 ENSDARG00000100366
#       - RSL24D1 ENSDARG00000040439
#       - RSL1D1 ENSDARG00000055868
#       - TOMM7 ENSDARG00000067717
#       - PPA1B ENSDARG00000030441
#       - EIF4EBP1 ENSDARG00000043608
#       - MGMT ENSDARG00000043275
#       - LLPH ENSDARG00000055360
#       - NHP2 ENSDARG00000069422
#       - CU927934.3 ENSDARG00000098037
#       - UQCC2 ENSDARG00000011272
#       - PFDN1 ENSDARG00000014536
#       - COX5AA ENSDARG00000088383
#       - RPS27.2 ENSDARG00000055475
#       - MRPS18A ENSDARG00000024465
#       - ZGC:162025 ENSDARG00000046141
#       - RPS4X ENSDARG00000014690
#       - ALCAMA ENSDARG00000026531
#       - DND1 ENSDARG00000022813
#       - DDX39AA ENSDARG00000006225
#       - ORG ENSDARG00000076474
#       - SI:DKEY-239H2.3 ENSDARG00000092033
#       - C1QBP ENSDARG00000039887
#       - HDAC1 ENSDARG00000015427
#       - RPLP2L ENSDARG00000011201
#       - TUBA8L ENSDARG00000042708
#       - STMN1A ENSDARG00000004169
#       - DDX18 ENSDARG00000030789
#       - EIF1AD ENSDARG00000016280
#       - RPLP0 ENSDARG00000051783
#       - UBE2E1 ENSDARG00000116649
#       - MTBL ENSDARG00000102051
#       - MRPL39 ENSDARG00000041570
#       - POLR3K ENSDARG00000037835
#       - CU929070.1 ENSDARG00000080372
#       - ADH8B ENSDARG00000024278
#       - SMFN ENSDARG00000009806
#       - COIL ENSDARG00000040070
#       - NOP53 ENSDARG00000100452
#       - SI:DKEY-28B4.7 ENSDARG00000079632
#       - ISG15 ENSDARG00000086374
#       - TMEM14CA ENSDARG00000110836
#       - PDCD4A ENSDARG00000021702
#       - RPS26 ENSDARG00000037071
#       - MRPS10 ENSDARG00000045913
#       - RPL18A ENSDARG00000025073
#       - SUPT3H ENSDARG00000098141
#       - RPL32 ENSDARG00000054818
#       - RPS3A ENSDARG00000035692
#       - SNU13B ENSDARG00000023299
#       - RPS26L ENSDARG00000030408
#       - TIMM10 ENSDARG00000069116
#       - CNBPB ENSDARG00000070922
#       - CCNG1 ENSDARG00000076667
#       - GYG1A ENSDARG00000011934
#       - TDRD9 ENSDARG00000013453
#       - EIF4EBP3 ENSDARG00000054916
#       - SERBP1A ENSDARG00000074242
#       - GSTA.1 ENSDARG00000090228
#       - RPS27.1 ENSDARG00000023298
#       - UBE2NB ENSDARG00000045877
#       - THYN1 ENSDARG00000042659
#       - TCEA2 ENSDARG00000012927
#       - TMEM258 ENSDARG00000078785
#       - RPL38 ENSDARG00000006413
#       - RPP30 ENSDARG00000027428
#       - ATP5IF1A ENSDARG00000067975
#       - RPS21 ENSDARG00000025850
#       - TIMM8B ENSDARG00000055708
#       - PSME2 ENSDARG00000033144
#       - GTPBP4 ENSDARG00000018961
#       - ADH5 ENSDARG00000080010
#       - ISCUB ENSDARG00000026582
#       - FKBP1AA ENSDARG00000022684
#       - ATP5F1C ENSDARG00000045514
#       - MRPL52 ENSDARG00000090568
#       - SI:DKEY-23I12.5 ENSDARG00000103682
#       - NOL12 ENSDARG00000038027
#       - HSPE1 ENSDARG00000056167
#       - TOMM5 ENSDARG00000068265
#       - PPP1R14AA ENSDARG00000011239
#       - MRTO4 ENSDARG00000007130
#       - PONZR1 ENSDARG00000090444
#       - DRG2 ENSDARG00000006642
#       - FP074902.2 ENSDARG00000105273
#       - SERPINB1 ENSDARG00000055416
#       - RPL4 ENSDARG00000041182
#       - QDPRB1 ENSDARG00000037378
#       - PDAP1A ENSDARG00000092546
#       - MRPS11 ENSDARG00000075129
#       - DDX4 ENSDARG00000014373
#       - RRP9 ENSDARG00000041991
#       - SNRPD3L ENSDARG00000076283
#       - RPS28 ENSDARG00000035860
#       - RPL17 ENSDARG00000057556
#       - IRF10 ENSDARG00000027658
#       - MRPL36 ENSDARG00000070607
#       - RPL28 ENSDARG00000005791
#       - ALDOAA ENSDARG00000011665
#       - TUBA8L2 ENSDARG00000031164
#       - IMP3 ENSDARG00000115266
#       - FBL ENSDARG00000053912
#       - AVD ENSDARG00000087961
#       - PIGBOS1 ENSDARG00000115717
#       - SMDT1B ENSDARG00000098852
#       - SEC61G ENSDARG00000018637
#       - RANGRF ENSDARG00000098786
#       - GPD1B ENSDARG00000043180
#       - ZGC:175088 ENSDARG00000099306
#       - DCTPP1 ENSDARG00000054334
#       - NOP16 ENSDARG00000044402
#       - RPS15A ENSDARG00000010160
#       - TXNDC17 ENSDARG00000058079
#       - NIP7 ENSDARG00000059075
#       - ATP5MC3B ENSDARG00000009447
#       - UQCC3 ENSDARG00000093382
#       - TRMT2A ENSDARG00000002830
#       - CNBPA ENSDARG00000045776
#       - BX511129.1 ENSDARG00000083520
#       - RPL10 ENSDARG00000025581
#       - NCCRP1 ENSDARG00000035326
#       - EIF3D ENSDARG00000021257
#       - SSBP1 ENSDARG00000039350
#       - RPL35A ENSDARG00000088030
#       - GNL3 ENSDARG00000006219
#       - ADAD2 ENSDARG00000105626
#       - PARK7 ENSDARG00000116835
#       - NACA ENSDARG00000005513
#       - RPS18 ENSDARG00000100392
#       - BXDC2 ENSDARG00000098935
#       - RPS25 ENSDARG00000041811
#       - NOP56 ENSDARG00000012820
#       - RPS19 ENSDARG00000030602
#       - SI:CH211-156B7.4 ENSDARG00000101707
#       - CCT5 ENSDARG00000045399
#       - MIF ENSDARG00000071336
#       - PRPS1B ENSDARG00000037506
#       - FIP1L1B ENSDARG00000070431
#       - BTF3L4 ENSDARG00000089681
#       - RRP7A ENSDARG00000098934
#       - GEMIN2 ENSDARG00000015638
#       - RPS14 ENSDARG00000036629
#       - FUOM ENSDARG00000039422
#       - DCAF13 ENSDARG00000002267
#       - FAM32A ENSDARG00000042660
#       - PPDPFB ENSDARG00000031317
#       - S100A10B ENSDARG00000025254
#       - ZGC:112496 ENSDARG00000004274
#       - RPS11 ENSDARG00000053058
#       - POLR2K ENSDARG00000075616
#       - RPL19 ENSDARG00000013307
#       - ZNHIT3 ENSDARG00000023950
#       - NOP2 ENSDARG00000043304
#       - RPL39 ENSDARG00000036316
#       - ZNRD1 ENSDARG00000036070
#       - RPS9 ENSDARG00000011405
#       - DDX47 ENSDARG00000102353
#       - MRPL32 ENSDARG00000060489
#       - RPL23A ENSDARG00000006316
#       - RPL18 ENSDARG00000029533
#       - RPL13A ENSDARG00000044093
#       - RTN4A ENSDARG00000044601
#       - SAP18 ENSDARG00000057854
#       - RNF7 ENSDARG00000055524
#       - RPL30 ENSDARG00000035871
#       - TDRD1 ENSDARG00000007465
#       - RRP8 ENSDARG00000071652
#       - CMSS1 ENSDARG00000112579
#       - RFC2 ENSDARG00000014274
#       - MTAP ENSDARG00000037261
#       - MRPL46 ENSDARG00000016307
#       - POP5 ENSDARG00000053452
#       - NME2B.1 ENSDARG00000103791
#       - RPS13 ENSDARG00000036298
#       - RPS7 ENSDARG00000042566
#       - NIFK ENSDARG00000040666
#       - EEF1DA ENSDARG00000102291
#       - RPS2 ENSDARG00000077291
#       - NFKBIAB ENSDARG00000007693
#       - WDR12 ENSDARG00000003287
#       - SI:CH211-285J22.3 ENSDARG00000100703
#       - NIPSNAP3A ENSDARG00000020387
#       - ACTR6 ENSDARG00000021370
#       - CDPF1 ENSDARG00000095705
#       - RPS6 ENSDARG00000019778
#       - RPS27A ENSDARG00000032725
#       - RPL23 ENSDARG00000053457
#       - MRPL22 ENSDARG00000109961
#       - FKBP6 ENSDARG00000030133
#       - RPL13 ENSDARG00000099380
#       - PTER ENSDARG00000063375
#       - DNMT3BB.1 ENSDARG00000036791
#       - BX005340.1 ENSDARG00000092373
#       - GADD45BA ENSDARG00000027744
#       - ZGC:113426 ENSDARG00000051793
#       - RPL5B ENSDARG00000015862
#       - BUD23 ENSDARG00000063596
#       - MRPL54 ENSDARG00000071468
#       - UPRT ENSDARG00000035549
#       - TREH ENSDARG00000077911
#       - HNRNPA1B ENSDARG00000036675
#       - YWHAQA ENSDARG00000042539
#       - SETB ENSDARG00000003920
#       - CFL1 ENSDARG00000021124
#       - CMC1 ENSDARG00000103670
#       - DBI ENSDARG00000026369
#       - RPLP1 ENSDARG00000021864
#       - EIF3F ENSDARG00000077533
#       - RPS5 ENSDARG00000043453
#       - RPL36A ENSDARG00000058105
#       - MRPL24 ENSDARG00000019222
#       - SNCB ENSDARG00000104945
#       - HGH1 ENSDARG00000101259
#       - SI:DKEY-33C12.4 ENSDARG00000057890
#       - BX927253.1 ENSDARG00000096072
#       - MCM3 ENSDARG00000024204
#       - SI:DKEY-287G12.6 ENSDARG00000096808
#       - TOMM22 ENSDARG00000045146
#       - GIG2O ENSDARG00000086903
#       - RPSA ENSDARG00000019181
#       - UBE2W ENSDARG00000044923
#       - IFI30 ENSDARG00000056378
#       - EEF1AKMT1 ENSDARG00000040584
#       - GSTR ENSDARG00000042620
#       - CYB5R2 ENSDARG00000051925
#       - TMEM237A ENSDARG00000041735
#       - RPL21 ENSDARG00000010516
#       - OTC ENSDARG00000062147
#       - ZGC:153681 ENSDARG00000086017
#       - RPL7A ENSDARG00000019230
#       - PPIB ENSDARG00000092798
#       - SI:DKEY-188I13.9 ENSDARG00000074754
#       - RFC3 ENSDARG00000055969
#       - FEN1 ENSDARG00000011404
#       - FDX1 ENSDARG00000056410
#       - MRPL21 ENSDARG00000003846
#       - PA2G4A ENSDARG00000039578
#       - MYL6 ENSDARG00000008494
#       - PHO ENSDARG00000035133
#       - KRI1 ENSDARG00000075380
#       - COQ3 ENSDARG00000069857
#       - AL954696.1 ENSDARG00000078442
#       - SI:DKEY-188I13.10 ENSDARG00000075151
#       - COX14 ENSDARG00000092124
#       - EMG1 ENSDARG00000056914
#       - SP100.2 ENSDARG00000102588
#       - PUM3 ENSDARG00000087779
#       - IAH1 ENSDARG00000015765
#       - DDX21 ENSDARG00000063626
#       - SMCO4 ENSDARG00000097824
#       - DDB2 ENSDARG00000041140
#       - NOC3L ENSDARG00000002487
#       - RIOX2 ENSDARG00000036359
#       - S100V2 ENSDARG00000070702
#       - DNTTIP2 ENSDARG00000057648
#       - PES ENSDARG00000018902
#       - PUS1 ENSDARG00000045562
#       - TOMM6 ENSDARG00000097797
#       - RFC4 ENSDARG00000042458
#       - PYURF ENSDARG00000045773
#       - TIGARB ENSDARG00000045858
#       - SI:DKEY-48P11.3 ENSDARG00000077926
#       - GCHFR ENSDARG00000098588
#       - RPL11 ENSDARG00000043509
#       - CDCA7B ENSDARG00000076659
#       - ZGC:92275 ENSDARG00000034048
#       - RPL36 ENSDARG00000100588
#       - HPGD ENSDARG00000012016
#       - PPAT ENSDARG00000004517
#       - PGD ENSDARG00000015343
#       - PHYHD1 ENSDARG00000029905
#       - SI:DKEY-42I9.8 ENSDARG00000071541
#       - PVALB2 ENSDARG00000002768
#       - CKBB ENSDARG00000043257
#       - EIF4BB ENSDARG00000010194
#       - RIOK2 ENSDARG00000035264
#       - TRMT112 ENSDARG00000071878
#       - PINX1 ENSDARG00000023532
#       - EIF3JB ENSDARG00000053370
#       - MRPS22 ENSDARG00000018073
#       - RPS16 ENSDARG00000045487
#       - MRPL43 ENSDARG00000076334
#       - RPUSD4 ENSDARG00000012674
#       - DKC1 ENSDARG00000016484
#       - CU655961.3 ENSDARG00000106724
#       - RPS12 ENSDARG00000036875
#       - B2ML ENSDARG00000015887
#       - CAT ENSDARG00000104702
#       - EIF2B2 ENSDARG00000041397
#       - MRPS34 ENSDARG00000057910
#       - TEX10 ENSDARG00000055885
#       - GSTO1 ENSDARG00000022183
#       - NCL ENSDARG00000002710
#       - GEMIN7 ENSDARG00000041011
#       - ARRDC1A ENSDARG00000068148
#       - PGAM1B ENSDARG00000014068
#       - RAB11BB ENSDARG00000090086
#       - PIWIL1 ENSDARG00000041699
#       - PSMB9A ENSDARG00000000656
#       - GSTM.3 ENSDARG00000088116
#       - BX649478.1 ENSDARG00000092351
#       - NDUFAF3 ENSDARG00000112931
#       - ADSSL ENSDARG00000012399
#       - CCDC137 ENSDARG00000104024
#       - CTPS1A ENSDARG00000030700
#   - name: Macrophage
#     markers:
#       - GRN2 ENSDARG00000088641
#       - GRN1 ENSDARG00000089362
#       - LYGL1 ENSDARG00000056874
#       - MFAP4 ENSDARG00000116066
#       - CD74B ENSDARG00000036628
#       - C1QB ENSDARG00000044612
#       - CR855311.1 ENSDARG00000090352
#       - F3B ENSDARG00000005673
#       - TMSB4X ENSDARG00000077777
#       - CEBPB ENSDARG00000042725
#       - S100A10B ENSDARG00000025254
#       - BX908782.2 ENSDARG00000101479
#       - C1QC ENSDARG00000095627
#       - TPPP ENSDARG00000105029
#       - TSPAN36 ENSDARG00000024540
#       - APOC1 ENSDARG00000092170
#       - SI:DKEY-5N18.1 ENSDARG00000043436
#       - ZGC:158343 ENSDARG00000099411
#       - CD74A ENSDARG00000009087
#       - CCL34A.4 ENSDARG00000090873
#       - PFN1 ENSDARG00000088091
#       - CR318588.1 ENSDARG00000092191
#       - FCER1GL ENSDARG00000104077
#       - LGMN ENSDARG00000039150
#       - ICN ENSDARG00000009978
#       - SI:CH211-147M6.2 ENSDARG00000103769
#       - CTSBA ENSDARG00000055120
#       - ACTB2 ENSDARG00000037870
#       - MCL1A ENSDARG00000009779
#       - NFKBIAA ENSDARG00000005481
#       - CD63 ENSDARG00000025147
#       - GADD45BA ENSDARG00000027744
#       - CRIP1 ENSDARG00000053858
#       - LGALS2A ENSDARG00000054942
#       - NPC2 ENSDARG00000096979
#       - CTSD ENSDARG00000057698
#       - ZGC:162730 ENSDARG00000103720
#       - SQSTM1 ENSDARG00000075014
#       - CXCL8B.1 ENSDARG00000102299
#       - ATP6V0CA ENSDARG00000057853
#       - SI:CH211-212K18.7 ENSDARG00000055504
#       - LAPTM5 ENSDARG00000101785
#       - MARCKSL1B ENSDARG00000035715
#       - NFKBIAB ENSDARG00000007693
#       - CR383676.1 ENSDARG00000099859
#       - STOML3B ENSDARG00000057035
#       - CKBB ENSDARG00000043257
#       - MARCO ENSDARG00000059294
#       - CR318588.4 ENSDARG00000095556
#       - TMSB1 ENSDARG00000104181
#       - GPX1A ENSDARG00000018146
#       - PONZR1 ENSDARG00000090444
#       - SDC4 ENSDARG00000059906
#       - PTMAB ENSDARG00000101766
#       - BHLHE40 ENSDARG00000004060
#       - CTSS2.1 ENSDARG00000074656
#       - LGALS3BPB ENSDARG00000040528
#       - SLC43A3B ENSDARG00000057949
#       - GRNA ENSDARG00000004954
#       - IER2A ENSDARG00000099195
#       - MHC2DAB ENSDARG00000079105
#       - CFL1 ENSDARG00000021124
#       - HSP70L ENSDARG00000055723
#       - JUNBB ENSDARG00000104773
#       - NR4A1 ENSDARG00000000796
#       - HSP70.2 ENSDARG00000092362
#       - SI:CH211-165I18.2 ENSDARG00000077239
#       - HSP70.1 ENSDARG00000029688
#       - SAMSN1A ENSDARG00000054543
#       - JUNBA ENSDARG00000074378
#       - CXCR4B ENSDARG00000041959
#       - CTSZ ENSDARG00000043081
#       - MHC1UBA ENSDARG00000075963
#       - ARHGDIG ENSDARG00000004034
#       - DRAM1 ENSDARG00000045561
#       - NPC2 ENSDARG00000096979
#       - CITED4B ENSDARG00000101009
#       - ACTB1 ENSDARG00000037746
#       - IER2B ENSDARG00000086881
#       - NCF1 ENSDARG00000033735
#       - PIM1 ENSDARG00000100020
#       - SCPEP1 ENSDARG00000040072
#       - HSP70.3 ENSDARG00000021924
#       - ARPC2 ENSDARG00000075989
#       - UBB ENSDARG00000093313
#       - B2M ENSDARG00000053136
#       - SI:DKEY-33I11.9 ENSDARG00000102555
#       - PGD ENSDARG00000015343
#       - ZGC:110239 ENSDARG00000077664
#       - GDA ENSDARG00000002986
#       - EEF1A1L1 ENSDARG00000020850
#       - LECT2L ENSDARG00000033227
#       - NME2B.1 ENSDARG00000103791
#       - GAPDHS ENSDARG00000039914
#       - SEC61G ENSDARG00000018637
#       - NAGA ENSDARG00000099313
#       - G0S2 ENSDARG00000078859
#       - HSP90AA1.2 ENSDARG00000024746
#       - PPIAB ENSDARG00000103994
#       - SRGN ENSDARG00000077069
#       - ITGB2 ENSDARG00000016939
#       - CTSC ENSDARG00000101334
#       - NKL.1 ENSDARG00000058673
#       - LAMTOR4 ENSDARG00000045542
#       - RPS25 ENSDARG00000041811
#       - RAB5AA ENSDARG00000018602
#       - VASPB ENSDARG00000017105
#       - RPS4X ENSDARG00000014690
#       - SI:CH1073-67J19.1 ENSDARG00000105096
#       - UCP2 ENSDARG00000043154
#   - name: Leydig cell
#     markers:
#       - LYZ ENSDARG00000057789
#       - LECT2L ENSDARG00000033227
#       - ICN ENSDARG00000009978
#       - BX908782.2 ENSDARG00000101479
#       - PFN1 ENSDARG00000088091
#       - TMSB4X ENSDARG00000077777
#       - NPSN ENSDARG00000010423
#       - SI:CH1073-67J19.1 ENSDARG00000105096
#       - CEBPB ENSDARG00000042725
#       - TMSB1 ENSDARG00000104181
#       - COTL1 ENSDARG00000026829
#       - ARPC1B ENSDARG00000027063
#       - ACTB2 ENSDARG00000037870
#       - LAPTM5 ENSDARG00000101785
#       - CR383676.1 ENSDARG00000099859
#       - CXCR4B ENSDARG00000041959
#       - STAR ENSDARG00000006137
#       - GSDF ENSDARG00000075301
#       - ARHGDIG ENSDARG00000004034
#       - HSP70.1 ENSDARG00000029688
#       - FCER1GL ENSDARG00000104077
#       - PTMAB ENSDARG00000101766
#       - HSP70L ENSDARG00000055723
#       - NCCRP1 ENSDARG00000035326
#       - SI:CH211-9D9.1 ENSDARG00000099839
#       - CORO1A ENSDARG00000054610
#       - MCL1A ENSDARG00000009779
#       - CR318588.4 ENSDARG00000095556
#       - PONZR1 ENSDARG00000090444
#       - ICN2 ENSDARG00000055514
#       - HSP70.2 ENSDARG00000092362
#       - S100A10B ENSDARG00000025254
#       - CD63 ENSDARG00000025147
#       - COX6B1 ENSDARG00000045230
#       - ZGC:64051 ENSDARG00000068233
#       - ACTB1 ENSDARG00000037746
#       - CFL1 ENSDARG00000021124
#       - NR4A1 ENSDARG00000000796
#       - HSP70.3 ENSDARG00000021924
#       - DNAJB1B ENSDARG00000041394
#       - CYP11C1 ENSDARG00000042014
#       - WASB ENSDARG00000026350
#       - CD74A ENSDARG00000009087
#       - CKBB ENSDARG00000043257
#       - UBB ENSDARG00000093313
#       - BHLHE40 ENSDARG00000004060
#       - ALDOAA ENSDARG00000011665
#       - SRGN ENSDARG00000077069
#       - NCF1 ENSDARG00000033735
#       - NFKBIAB ENSDARG00000007693
#       - B2M ENSDARG00000053136
#       - TUBA8L ENSDARG00000042708
#       - RACK1 ENSDARG00000041619
#       - HSP90AA1.2 ENSDARG00000024746
#       - CD74B ENSDARG00000036628
#       - EEF1A1L1 ENSDARG00000020850
#       - SLA2 ENSDARG00000020788
#       - ZFP36L1B ENSDARG00000021443
#       - HMGN6 ENSDARG00000087636
#       - F3B ENSDARG00000005673
#       - RPL7A ENSDARG00000019230
#       - PPDPFA ENSDARG00000007682
#       - MHC2DAB ENSDARG00000079105
#       - IER2A ENSDARG00000099195
#       - RPS6 ENSDARG00000019778
#       - FO203432.1 ENSDARG00000115195
#       - ZGC:110239 ENSDARG00000077664
#       - RPS4X ENSDARG00000014690
#       - RPL10A ENSDARG00000042905
#       - RPL8 ENSDARG00000014867
#       - RPL13A ENSDARG00000044093
#       - RPL3 ENSDARG00000003599
#       - RPS18 ENSDARG00000100392
#       - FDX1B ENSDARG00000038956
#       - RPL18 ENSDARG00000029533
#       - RPS11 ENSDARG00000053058
#       - RPL18A ENSDARG00000025073
#       - ATF3 ENSDARG00000007823
#       - RPL30 ENSDARG00000035871
#       - PDE9A ENSDARG00000060280
#       - RPS27A ENSDARG00000032725
#   - name: Innate immune cell
#     markers:
#       - SI:DKEYP-75B4.10 ENSDARG00000079043
#       - SI:DKEY-203A12.2 ENSDARG00000102271
#       - SI:DKEY-203A12.9 ENSDARG00000104721
#       - CABZ01058647.1 ENSDARG00000117107
#       - BX322787.1 ENSDARG00000105779
#       - SI:DKEY-203A12.5 ENSDARG00000099673
#       - SI:CH211-14A17.10 ENSDARG00000076534
#       - CST14B.2 ENSDARG00000112540
#       - SI:CH211-214P16.1 ENSDARG00000044129
#       - CCL34B.9 ENSDARG00000078205
#       - ITLN1 ENSDARG00000095082
#       - SI:CH1073-110A20.2 ENSDARG00000092806
#       - SI:DKEY-203A12.7 ENSDARG00000099811
#       - SI:DKEY-77G12.4 ENSDARG00000103336
#       - PFN1 ENSDARG00000088091
#       - C3A.4 ENSDARG00000093198
#       - ACTB2 ENSDARG00000037870
#       - ICN ENSDARG00000009978
#       - CORO1A ENSDARG00000054610
#       - TMSB4X ENSDARG00000077777
#       - CR383676.1 ENSDARG00000099859
#       - HSP70.3 ENSDARG00000021924
#       - HSP70L ENSDARG00000055723
#       - NME2B.1 ENSDARG00000103791
#       - CR318588.4 ENSDARG00000095556
#       - HMGN6 ENSDARG00000087636
#       - RPL17 ENSDARG00000057556
#       - CD74B ENSDARG00000036628
#       - EEF1A1L1 ENSDARG00000020850
#       - MACO1B ENSDARG00000012741
#       - RPL21 ENSDARG00000010516
#       - SI:CH211-5K11.8 ENSDARG00000079078
#       - ALDOAA ENSDARG00000011665
#       - PGLS ENSDARG00000021233
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
#                                               SUMMARY
# ----------------------------------------------------------------------------------------------------
#
#
#     metadata:
#         id: 1708882982698910
#         list_name: zebrafish_gene_cellType
#         organism:
#             organism_name: zebrafish
#             taxonomy_id: 7955
#         marker_type: Genes
#         submitter:
#             name: Quintanilla, Marta
#         date: 25.02.2024
#     marker_list:
#       - name: Spermatid
#         markers:
#           - SI:CH211-121A2.2 ENSDARG00000039682
#           - CREMB ENSDARG00000102899
#           - BX004999.1 ENSDARG00000096792
#           - FAM166B ENSDARG00000100292
#           - TEKT1 ENSDARG00000101331
#           - SI:CH211-242F23.3 ENSDARG00000095223
#           - CCDC103 ENSDARG00000053455
#           - DNALI1 ENSDARG00000069815
#           - FANK1 ENSDARG00000039657
#           - FAM183A ENSDARG00000087144
#           - CKBA ENSDARG00000069752
#           - TP53INP2 ENSDARG00000088178
#           - SI:CH211-147D7.5 ENSDARG00000095457
#           - SI:CH211-141O9.10 ENSDARG00000077900
#           - CFAP126 ENSDARG00000070868
#           - ODF3B ENSDARG00000042396
#           - CFAP77 ENSDARG00000068122
#           - SI:CH211-163L21.7 ENSDARG00000034457
#           - EPHX1 ENSDARG00000042854
#           - SI:DKEY-58J15.10 ENSDARG00000096515
#           - SI:DKEY-11C5.11 ENSDARG00000096637
#           - SI:CH211-110E21.3 ENSDARG00000089338
#           - SI:CH211-248E11.2 ENSDARG00000058940
#           - SI:DKEYP-81F3.4 ENSDARG00000105458
#           - UBE2H ENSDARG00000000019
#           - FBXO36B ENSDARG00000039152
#           - DEGS2 ENSDARG00000042544
#           - ROPN1L ENSDARG00000058370
#           - DNAI1.1 ENSDARG00000100081
#           - SI:DKEYP-50B9.1 ENSDARG00000097421
#           - CFAP52 ENSDARG00000101679
#           - PVALB6 ENSDARG00000009311
#           - PPM1BA ENSDARG00000001888
#           - ZGC:153665 ENSDARG00000043442
#           - SI:DKEY-43K4.3 ENSDARG00000052428
#           - TMEM218 ENSDARG00000027129
#           - FLJ11011L ENSDARG00000045360
#           - SI:CH211-209A2.2 ENSDARG00000093734
#           - TPD52 ENSDARG00000061713
#           - SI:DKEY-42P14.3 ENSDARG00000092825
#           - SI:CH73-111K22.3 ENSDARG00000103492
#           - SI:CH211-107E6.5 ENSDARG00000097573
#           - IFT81 ENSDARG00000007444
#           - MLF1 ENSDARG00000077301
#           - PACRG ENSDARG00000087556
#           - CFAP206 ENSDARG00000021997
#           - SI:DKEY-70B23.2 ENSDARG00000093783
#           - CATIP ENSDARG00000063009
#           - SPACA9 ENSDARG00000068130
#           - MIF4GDB ENSDARG00000102578
#           - LENG9 ENSDARG00000062374
#           - SI:DKEY-86L18.10 ENSDARG00000105528
#           - UBE2R2 ENSDARG00000058740
#           - IFT80 ENSDARG00000038879
#           - CART3 ENSDARG00000035852
#           - LRRC51 ENSDARG00000040668
#           - MAATS1 ENSDARG00000006292
#           - RAB36 ENSDARG00000014058
#           - MEIG1 ENSDARG00000045705
#           - BTBD16 ENSDARG00000027710
#           - NFATC2IP ENSDARG00000011360
#           - SI:DKEY-27P23.3 ENSDARG00000075714
#           - ENO4 ENSDARG00000070598
#           - NEK2 ENSDARG00000005619
#           - DNAI2A ENSDARG00000100285
#           - CFAP45 ENSDARG00000068103
#           - HHLA2A.1 ENSDARG00000043182
#           - SUMO1 ENSDARG00000044267
#           - IQCG ENSDARG00000068678
#           - ENKUR ENSDARG00000031248
#           - SI:CH211-122L24.6 ENSDARG00000112759
#           - CAPSLA ENSDARG00000103521
#           - SI:DKEY-111E8.4 ENSDARG00000093547
#           - CBY1 ENSDARG00000077409
#           - CFAP53 ENSDARG00000100892
#           - SAXO2 ENSDARG00000006474
#           - SINUP ENSDARG00000017163
#           - IQCD ENSDARG00000035551
#           - COQ9 ENSDARG00000023583
#           - CR382372.1 ENSDARG00000096684
#           - SRGN ENSDARG00000077069
#           - DCST2 ENSDARG00000088693
#           - USP2A ENSDARG00000020107
#           - AL928901.1 ENSDARG00000100960
#           - SI:CH211-284K5.2 ENSDARG00000101455
#           - CCDC166 ENSDARG00000101235
#           - BX284635.1 ENSDARG00000092456
#           - UBE2B ENSDARG00000026035
#           - C2CD2L ENSDARG00000061066
#           - FXYD6L ENSDARG00000097057
#           - DMC1 ENSDARG00000055883
#           - SI:DKEYP-110G5.4 ENSDARG00000092482
#           - IQUB ENSDARG00000061899
#           - PPP1R42 ENSDARG00000057632
#           - PPP6R2A ENSDARG00000045540
#           - RAG2 ENSDARG00000052121
#           - SI:CH211-226M16.3 ENSDARG00000026864
#           - TSNAXIP1 ENSDARG00000030512
#           - PRKAR1AB ENSDARG00000101755
#           - STYXL1 ENSDARG00000026338
#           - ZMYND12 ENSDARG00000017055
#           - CR847939.1 ENSDARG00000100639
#           - SI:CH211-69G19.2 ENSDARG00000070656
#           - ZGC:123244 ENSDARG00000056144
#           - DHRS9 ENSDARG00000019260
#           - FOXM1 ENSDARG00000003200
#           - SI:CH211-116O3.5 ENSDARG00000097692
#           - TEX9 ENSDARG00000010586
#           - SI:CH1073-82L19.1 ENSDARG00000101799
#           - SI:CH211-152P11.4 ENSDARG00000079705
#           - KCNN4 ENSDARG00000086091
#           - WBP2 ENSDARG00000056605
#           - BX640520.3 ENSDARG00000095363
#           - PREP ENSDARG00000057151
#           - TLR5A ENSDARG00000044415
#           - TTC23 ENSDARG00000022160
#           - NPTX2A ENSDARG00000037794
#           - FOSL1B ENSDARG00000079373
#           - POLB ENSDARG00000003749
#           - DNAAF3L ENSDARG00000036304
#           - SPAG8 ENSDARG00000103843
#           - SI:CH211-10A23.2 ENSDARG00000060656
#           - ZGC:172182 ENSDARG00000039824
#           - NUSAP1 ENSDARG00000002403
#           - BX539313.2 ENSDARG00000097454
#           - SI:CH211-272N13.3 ENSDARG00000099768
#           - UBE2J2 ENSDARG00000061161
#           - PHLDA2 ENSDARG00000042874
#           - SI:CH211-176L24.4 ENSDARG00000097203
#           - BX950187.1 ENSDARG00000095282
#           - WDR95 ENSDARG00000054572
#           - FAM221A ENSDARG00000027599
#           - SI:DKEY-77F5.4 ENSDARG00000097808
#           - ZGC:153215 ENSDARG00000055889
#           - CDKL1 ENSDARG00000017329
#           - NFE2L3 ENSDARG00000019810
#           - ZGC:194114 ENSDARG00000074950
#           - SI:CH73-141C7.1 ENSDARG00000009040
#           - SI:CH211-9N13.3 ENSDARG00000093432
#           - SI:CH211-63O20.7 ENSDARG00000042000
#           - SPINT1A ENSDARG00000102332
#           - TTC12 ENSDARG00000056896
#           - PNRC1 ENSDARG00000043904
#           - FAM219AA ENSDARG00000016396
#           - SI:CH211-151H10.2 ENSDARG00000068250
#           - PPCDC ENSDARG00000033020
#           - DNAJB2 ENSDARG00000058644
#           - BX890548.1 ENSDARG00000099355
#           - ATF7IP ENSDARG00000069619
#           - KNOP1 ENSDARG00000077721
#           - CCDC87 ENSDARG00000045683
#           - AGBL2 ENSDARG00000079983
#           - FIBPA ENSDARG00000016058
#           - CCNA1 ENSDARG00000043236
#           - SI:DKEY-57A22.11 ENSDARG00000092651
#           - TRAF3IP1 ENSDARG00000010300
#           - CR855277.2 ENSDARG00000092801
#           - ITCHA ENSDARG00000074903
#           - DZIP1L ENSDARG00000074265
#           - FXYD1 ENSDARG00000099014
#           - MSH5 ENSDARG00000077479
#           - HSBP1L1 ENSDARG00000075984
#           - CU657980.1 ENSDARG00000054846
#           - CFAP43 ENSDARG00000001825
#           - LO018541.1 ENSDARG00000107593
#           - BX005254.1 ENSDARG00000093797
#           - SAT1B ENSDARG00000032272
#           - TAC3A ENSDARG00000093089
#           - SI:CH211-271E10.1 ENSDARG00000095735
#           - FAAP24 ENSDARG00000051731
#           - KLHL26 ENSDARG00000053876
#           - CCDC88AA ENSDARG00000078440
#           - RAD9B ENSDARG00000075632
#           - KIF11 ENSDARG00000010948
#           - XRRA1 ENSDARG00000089578
#           - PIP5K1BB ENSDARG00000006508
#           - CERKL ENSDARG00000079397
#           - BX649411.2 ENSDARG00000105079
#           - EIF4G3A ENSDARG00000077215
#           - MUSTN1A ENSDARG00000054026
#           - HBBA1 ENSDARG00000097238
#           - CU468164.1 ENSDARG00000052609
#           - ZGC:194627 ENSDARG00000102594
#           - KLHL24A ENSDARG00000021739
#           - CSNK1G1 ENSDARG00000104342
#           - NCBP3 ENSDARG00000044597
#           - PHF23A ENSDARG00000030887
#           - SLC39A9 ENSDARG00000070447
#           - JOSD2 ENSDARG00000057626
#           - BX465227.1 ENSDARG00000097825
#           - KIF20A ENSDARG00000044491
#           - CCDC78 ENSDARG00000030095
#           - AK9 ENSDARG00000021913
#       - name: Spermatocyte
#         markers:
#           - NOP56 ENSDARG00000012820
#           - STMN1A ENSDARG00000004169
#           - SETB ENSDARG00000003920
#           - METAP2B ENSDARG00000102571
#           - TUBB2B ENSDARG00000098591
#           - PCNA ENSDARG00000054155
#           - HMGN2 ENSDARG00000099572
#           - DKC1 ENSDARG00000016484
#           - SUMO3B ENSDARG00000035993
#           - HP1BP3 ENSDARG00000044669
#           - NPM1A ENSDARG00000014329
#           - GSTR ENSDARG00000042620
#           - LSM7 ENSDARG00000058328
#           - SERBP1A ENSDARG00000074242
#           - TUBA8L4 ENSDARG00000006260
#           - NCL ENSDARG00000002710
#           - SI:CH73-281N10.2 ENSDARG00000097102
#           - DEK ENSDARG00000070108
#           - SI:CH211-156B7.4 ENSDARG00000101707
#           - RPLP2L ENSDARG00000011201
#           - RPS4X ENSDARG00000014690
#           - KHDRBS1A ENSDARG00000052856
#           - MCM4 ENSDARG00000040041
#           - FOSAB ENSDARG00000031683
#           - DAZL ENSDARG00000036214
#           - YWHAQA ENSDARG00000042539
#           - HSPE1 ENSDARG00000056167
#           - SI:CH211-288G17.3 ENSDARG00000070959
#           - BTF3L4 ENSDARG00000089681
#           - MCM3 ENSDARG00000024204
#           - ATP5F1C ENSDARG00000045514
#           - H3F3B.1 ENSDARG00000068434
#           - MIF ENSDARG00000071336
#           - MCM5 ENSDARG00000019507
#           - NOP58 ENSDARG00000104353
#           - GSTP1 ENSDARG00000104068
#           - RCC2 ENSDARG00000011510
#           - PPIAB ENSDARG00000103994
#           - RPL32 ENSDARG00000054818
#           - DNAJC9 ENSDARG00000031293
#           - MCM6 ENSDARG00000057683
#           - HNRNPABB ENSDARG00000099865
#           - PA2G4A ENSDARG00000039578
#           - ASF1BB ENSDARG00000043713
#           - CBX3A ENSDARG00000003860
#           - SMFN ENSDARG00000009806
#           - TXNDC17 ENSDARG00000058079
#           - MYL12.1 ENSDARG00000099766
#           - DDX4 ENSDARG00000014373
#           - BANF1 ENSDARG00000037009
#           - SI:CH211-226L4.6 ENSDARG00000105573
#           - EEF2B ENSDARG00000100371
#           - PPA1B ENSDARG00000030441
#           - ILF2 ENSDARG00000014591
#           - EIF3G ENSDARG00000016889
#           - SI:CH73-1A9.3 ENSDARG00000103919
#           - NIP7 ENSDARG00000059075
#           - DDX18 ENSDARG00000030789
#           - RPL18A ENSDARG00000025073
#           - FEN1 ENSDARG00000011404
#           - MGMT ENSDARG00000043275
#           - FBL ENSDARG00000053912
#           - RPL38 ENSDARG00000006413
#           - RPS5 ENSDARG00000043453
#           - MRPL54 ENSDARG00000071468
#           - POLR2K ENSDARG00000075616
#           - ADH5 ENSDARG00000080010
#           - COIL ENSDARG00000040070
#           - TIMM10 ENSDARG00000069116
#           - APEX1 ENSDARG00000045843
#           - CFL1 ENSDARG00000021124
#           - NASP ENSDARG00000039208
#           - ATP5IF1A ENSDARG00000067975
#           - ZGC:162025 ENSDARG00000046141
#           - HMGB2A ENSDARG00000029722
#           - RPS6 ENSDARG00000019778
#           - DUT ENSDARG00000106529
#           - CNBPB ENSDARG00000070922
#           - CDCA7A ENSDARG00000077620
#           - CCT5 ENSDARG00000045399
#           - HMGN6 ENSDARG00000087636
#           - LBR ENSDARG00000014013
#           - RPS25 ENSDARG00000041811
#           - GSTM.1 ENSDARG00000042533
#           - RPS26 ENSDARG00000037071
#           - CHTOPB ENSDARG00000070430
#           - SI:DKEY-239H2.3 ENSDARG00000092033
#           - MGST3B ENSDARG00000033364
#           - MRPL36 ENSDARG00000070607
#           - ADSSL ENSDARG00000012399
#           - RPL4 ENSDARG00000041182
#           - MRPS18A ENSDARG00000024465
#           - CIRBPA ENSDARG00000103672
#           - RBBP4 ENSDARG00000029058
#           - EIF3D ENSDARG00000021257
#           - RPL36A ENSDARG00000058105
#           - MRTO4 ENSDARG00000007130
#           - RACK1 ENSDARG00000041619
#           - RPS12 ENSDARG00000036875
#           - HDAC1 ENSDARG00000015427
#           - PDAP1A ENSDARG00000092546
#           - RPS21 ENSDARG00000025850
#           - PES ENSDARG00000018902
#           - RPL5B ENSDARG00000015862
#           - GAPDHS ENSDARG00000039914
#           - ATP5MC3B ENSDARG00000009447
#           - RPL36 ENSDARG00000100588
#           - SETA ENSDARG00000031495
#           - RPL23A ENSDARG00000006316
#           - RPL13A ENSDARG00000044093
#           - TRMT112 ENSDARG00000071878
#           - MIBP ENSDARG00000101362
#           - RRM1 ENSDARG00000014017
#           - ANP32B ENSDARG00000023330
#           - RPS28 ENSDARG00000035860
#           - SIVA1 ENSDARG00000114552
#           - CDC6 ENSDARG00000009942
#           - RPS11 ENSDARG00000053058
#           - HSPD1 ENSDARG00000056160
#           - PHO ENSDARG00000035133
#           - RPS27.2 ENSDARG00000055475
#           - NACA ENSDARG00000005513
#           - RPLP1 ENSDARG00000021864
#           - RSL1D1 ENSDARG00000055868
#           - RSL24D1 ENSDARG00000040439
#           - TOMM7 ENSDARG00000067717
#           - TARDBP ENSDARG00000040031
#           - RPL13 ENSDARG00000099380
#           - MCL1A ENSDARG00000009779
#           - GAR1 ENSDARG00000076526
#           - COX5AA ENSDARG00000088383
#           - PARK7 ENSDARG00000116835
#           - MARCKSB ENSDARG00000008803
#           - SI:ZFOS-169G10.3 ENSDARG00000099309
#           - RPL35A ENSDARG00000088030
#           - RPS18 ENSDARG00000100392
#           - COX14 ENSDARG00000092124
#           - SI:CH211-282B22.1 ENSDARG00000097630
#           - IMP3 ENSDARG00000115266
#           - HNRNPA0B ENSDARG00000036162
#           - RPS13 ENSDARG00000036298
#           - SI:DKEY-33C12.4 ENSDARG00000057890
# ...
#           - RPL35A ENSDARG00000088030
#           - GNL3 ENSDARG00000006219
#           - ADAD2 ENSDARG00000105626
#           - PARK7 ENSDARG00000116835
#           - NACA ENSDARG00000005513
#           - RPS18 ENSDARG00000100392
#           - BXDC2 ENSDARG00000098935
#           - RPS25 ENSDARG00000041811
#           - NOP56 ENSDARG00000012820
#           - RPS19 ENSDARG00000030602
#           - SI:CH211-156B7.4 ENSDARG00000101707
#           - CCT5 ENSDARG00000045399
#           - MIF ENSDARG00000071336
#           - PRPS1B ENSDARG00000037506
#           - FIP1L1B ENSDARG00000070431
#           - BTF3L4 ENSDARG00000089681
#           - RRP7A ENSDARG00000098934
#           - GEMIN2 ENSDARG00000015638
#           - RPS14 ENSDARG00000036629
#           - FUOM ENSDARG00000039422
#           - DCAF13 ENSDARG00000002267
#           - FAM32A ENSDARG00000042660
#           - PPDPFB ENSDARG00000031317
#           - S100A10B ENSDARG00000025254
#           - ZGC:112496 ENSDARG00000004274
#           - RPS11 ENSDARG00000053058
#           - POLR2K ENSDARG00000075616
#           - RPL19 ENSDARG00000013307
#           - ZNHIT3 ENSDARG00000023950
#           - NOP2 ENSDARG00000043304
#           - RPL39 ENSDARG00000036316
#           - ZNRD1 ENSDARG00000036070
#           - RPS9 ENSDARG00000011405
#           - DDX47 ENSDARG00000102353
#           - MRPL32 ENSDARG00000060489
#           - RPL23A ENSDARG00000006316
#           - RPL18 ENSDARG00000029533
#           - RPL13A ENSDARG00000044093
#           - RTN4A ENSDARG00000044601
#           - SAP18 ENSDARG00000057854
#           - RNF7 ENSDARG00000055524
#           - RPL30 ENSDARG00000035871
#           - TDRD1 ENSDARG00000007465
#           - RRP8 ENSDARG00000071652
#           - CMSS1 ENSDARG00000112579
#           - RFC2 ENSDARG00000014274
#           - MTAP ENSDARG00000037261
#           - MRPL46 ENSDARG00000016307
#           - POP5 ENSDARG00000053452
#           - NME2B.1 ENSDARG00000103791
#           - RPS13 ENSDARG00000036298
#           - RPS7 ENSDARG00000042566
#           - NIFK ENSDARG00000040666
#           - EEF1DA ENSDARG00000102291
#           - RPS2 ENSDARG00000077291
#           - NFKBIAB ENSDARG00000007693
#           - WDR12 ENSDARG00000003287
#           - SI:CH211-285J22.3 ENSDARG00000100703
#           - NIPSNAP3A ENSDARG00000020387
#           - ACTR6 ENSDARG00000021370
#           - CDPF1 ENSDARG00000095705
#           - RPS6 ENSDARG00000019778
#           - RPS27A ENSDARG00000032725
#           - RPL23 ENSDARG00000053457
#           - MRPL22 ENSDARG00000109961
#           - FKBP6 ENSDARG00000030133
#           - RPL13 ENSDARG00000099380
#           - PTER ENSDARG00000063375
#           - DNMT3BB.1 ENSDARG00000036791
#           - BX005340.1 ENSDARG00000092373
#           - GADD45BA ENSDARG00000027744
#           - ZGC:113426 ENSDARG00000051793
#           - RPL5B ENSDARG00000015862
#           - BUD23 ENSDARG00000063596
#           - MRPL54 ENSDARG00000071468
#           - UPRT ENSDARG00000035549
#           - TREH ENSDARG00000077911
#           - HNRNPA1B ENSDARG00000036675
#           - YWHAQA ENSDARG00000042539
#           - SETB ENSDARG00000003920
#           - CFL1 ENSDARG00000021124
#           - CMC1 ENSDARG00000103670
#           - DBI ENSDARG00000026369
#           - RPLP1 ENSDARG00000021864
#           - EIF3F ENSDARG00000077533
#           - RPS5 ENSDARG00000043453
#           - RPL36A ENSDARG00000058105
#           - MRPL24 ENSDARG00000019222
#           - SNCB ENSDARG00000104945
#           - HGH1 ENSDARG00000101259
#           - SI:DKEY-33C12.4 ENSDARG00000057890
#           - BX927253.1 ENSDARG00000096072
#           - MCM3 ENSDARG00000024204
#           - SI:DKEY-287G12.6 ENSDARG00000096808
#           - TOMM22 ENSDARG00000045146
#           - GIG2O ENSDARG00000086903
#           - RPSA ENSDARG00000019181
#           - UBE2W ENSDARG00000044923
#           - IFI30 ENSDARG00000056378
#           - EEF1AKMT1 ENSDARG00000040584
#           - GSTR ENSDARG00000042620
#           - CYB5R2 ENSDARG00000051925
#           - TMEM237A ENSDARG00000041735
#           - RPL21 ENSDARG00000010516
#           - OTC ENSDARG00000062147
#           - ZGC:153681 ENSDARG00000086017
#           - RPL7A ENSDARG00000019230
#           - PPIB ENSDARG00000092798
#           - SI:DKEY-188I13.9 ENSDARG00000074754
#           - RFC3 ENSDARG00000055969
#           - FEN1 ENSDARG00000011404
#           - FDX1 ENSDARG00000056410
#           - MRPL21 ENSDARG00000003846
#           - PA2G4A ENSDARG00000039578
#           - MYL6 ENSDARG00000008494
#           - PHO ENSDARG00000035133
#           - KRI1 ENSDARG00000075380
#           - COQ3 ENSDARG00000069857
#           - AL954696.1 ENSDARG00000078442
#           - SI:DKEY-188I13.10 ENSDARG00000075151
#           - COX14 ENSDARG00000092124
#           - EMG1 ENSDARG00000056914
#           - SP100.2 ENSDARG00000102588
#           - PUM3 ENSDARG00000087779
#           - IAH1 ENSDARG00000015765
#           - DDX21 ENSDARG00000063626
#           - SMCO4 ENSDARG00000097824
#           - DDB2 ENSDARG00000041140
#           - NOC3L ENSDARG00000002487
#           - RIOX2 ENSDARG00000036359
#           - S100V2 ENSDARG00000070702
#           - DNTTIP2 ENSDARG00000057648
#           - PES ENSDARG00000018902
#           - PUS1 ENSDARG00000045562
#           - TOMM6 ENSDARG00000097797
#           - RFC4 ENSDARG00000042458
#           - PYURF ENSDARG00000045773
#           - TIGARB ENSDARG00000045858
#           - SI:DKEY-48P11.3 ENSDARG00000077926
#           - GCHFR ENSDARG00000098588
#           - RPL11 ENSDARG00000043509
#           - CDCA7B ENSDARG00000076659
#           - ZGC:92275 ENSDARG00000034048
#           - RPL36 ENSDARG00000100588
#           - HPGD ENSDARG00000012016
#           - PPAT ENSDARG00000004517
#           - PGD ENSDARG00000015343
#           - PHYHD1 ENSDARG00000029905
#           - SI:DKEY-42I9.8 ENSDARG00000071541
#           - PVALB2 ENSDARG00000002768
#           - CKBB ENSDARG00000043257
#           - EIF4BB ENSDARG00000010194
#           - RIOK2 ENSDARG00000035264
#           - TRMT112 ENSDARG00000071878
#           - PINX1 ENSDARG00000023532
#           - EIF3JB ENSDARG00000053370
#           - MRPS22 ENSDARG00000018073
#           - RPS16 ENSDARG00000045487
#           - MRPL43 ENSDARG00000076334
#           - RPUSD4 ENSDARG00000012674
#           - DKC1 ENSDARG00000016484
#           - CU655961.3 ENSDARG00000106724
#           - RPS12 ENSDARG00000036875
#           - B2ML ENSDARG00000015887
#           - CAT ENSDARG00000104702
#           - EIF2B2 ENSDARG00000041397
#           - MRPS34 ENSDARG00000057910
#           - TEX10 ENSDARG00000055885
#           - GSTO1 ENSDARG00000022183
#           - NCL ENSDARG00000002710
#           - GEMIN7 ENSDARG00000041011
#           - ARRDC1A ENSDARG00000068148
#           - PGAM1B ENSDARG00000014068
#           - RAB11BB ENSDARG00000090086
#           - PIWIL1 ENSDARG00000041699
#           - PSMB9A ENSDARG00000000656
#           - GSTM.3 ENSDARG00000088116
#           - BX649478.1 ENSDARG00000092351
#           - NDUFAF3 ENSDARG00000112931
#           - ADSSL ENSDARG00000012399
#           - CCDC137 ENSDARG00000104024
#           - CTPS1A ENSDARG00000030700
#       - name: Macrophage
#         markers:
#           - GRN2 ENSDARG00000088641
#           - GRN1 ENSDARG00000089362
#           - LYGL1 ENSDARG00000056874
#           - MFAP4 ENSDARG00000116066
#           - CD74B ENSDARG00000036628
#           - C1QB ENSDARG00000044612
#           - CR855311.1 ENSDARG00000090352
#           - F3B ENSDARG00000005673
#           - TMSB4X ENSDARG00000077777
#           - CEBPB ENSDARG00000042725
#           - S100A10B ENSDARG00000025254
#           - BX908782.2 ENSDARG00000101479
#           - C1QC ENSDARG00000095627
#           - TPPP ENSDARG00000105029
#           - TSPAN36 ENSDARG00000024540
#           - APOC1 ENSDARG00000092170
#           - SI:DKEY-5N18.1 ENSDARG00000043436
#           - ZGC:158343 ENSDARG00000099411
#           - CD74A ENSDARG00000009087
#           - CCL34A.4 ENSDARG00000090873
#           - PFN1 ENSDARG00000088091
#           - CR318588.1 ENSDARG00000092191
#           - FCER1GL ENSDARG00000104077
#           - LGMN ENSDARG00000039150
#           - ICN ENSDARG00000009978
#           - SI:CH211-147M6.2 ENSDARG00000103769
#           - CTSBA ENSDARG00000055120
#           - ACTB2 ENSDARG00000037870
#           - MCL1A ENSDARG00000009779
#           - NFKBIAA ENSDARG00000005481
#           - CD63 ENSDARG00000025147
#           - GADD45BA ENSDARG00000027744
#           - CRIP1 ENSDARG00000053858
#           - LGALS2A ENSDARG00000054942
#           - NPC2 ENSDARG00000096979
#           - CTSD ENSDARG00000057698
#           - ZGC:162730 ENSDARG00000103720
#           - SQSTM1 ENSDARG00000075014
#           - CXCL8B.1 ENSDARG00000102299
#           - ATP6V0CA ENSDARG00000057853
#           - SI:CH211-212K18.7 ENSDARG00000055504
#           - LAPTM5 ENSDARG00000101785
#           - MARCKSL1B ENSDARG00000035715
#           - NFKBIAB ENSDARG00000007693
#           - CR383676.1 ENSDARG00000099859
#           - STOML3B ENSDARG00000057035
#           - CKBB ENSDARG00000043257
#           - MARCO ENSDARG00000059294
#           - CR318588.4 ENSDARG00000095556
#           - TMSB1 ENSDARG00000104181
#           - GPX1A ENSDARG00000018146
#           - PONZR1 ENSDARG00000090444
#           - SDC4 ENSDARG00000059906
#           - PTMAB ENSDARG00000101766
#           - BHLHE40 ENSDARG00000004060
#           - CTSS2.1 ENSDARG00000074656
#           - LGALS3BPB ENSDARG00000040528
#           - SLC43A3B ENSDARG00000057949
#           - GRNA ENSDARG00000004954
#           - IER2A ENSDARG00000099195
#           - MHC2DAB ENSDARG00000079105
#           - CFL1 ENSDARG00000021124
#           - HSP70L ENSDARG00000055723
#           - JUNBB ENSDARG00000104773
#           - NR4A1 ENSDARG00000000796
#           - HSP70.2 ENSDARG00000092362
#           - SI:CH211-165I18.2 ENSDARG00000077239
#           - HSP70.1 ENSDARG00000029688
#           - SAMSN1A ENSDARG00000054543
#           - JUNBA ENSDARG00000074378
#           - CXCR4B ENSDARG00000041959
#           - CTSZ ENSDARG00000043081
#           - MHC1UBA ENSDARG00000075963
#           - ARHGDIG ENSDARG00000004034
#           - DRAM1 ENSDARG00000045561
#           - NPC2 ENSDARG00000096979
#           - CITED4B ENSDARG00000101009
#           - ACTB1 ENSDARG00000037746
#           - IER2B ENSDARG00000086881
#           - NCF1 ENSDARG00000033735
#           - PIM1 ENSDARG00000100020
#           - SCPEP1 ENSDARG00000040072
#           - HSP70.3 ENSDARG00000021924
#           - ARPC2 ENSDARG00000075989
#           - UBB ENSDARG00000093313
#           - B2M ENSDARG00000053136
#           - SI:DKEY-33I11.9 ENSDARG00000102555
#           - PGD ENSDARG00000015343
#           - ZGC:110239 ENSDARG00000077664
#           - GDA ENSDARG00000002986
#           - EEF1A1L1 ENSDARG00000020850
#           - LECT2L ENSDARG00000033227
#           - NME2B.1 ENSDARG00000103791
#           - GAPDHS ENSDARG00000039914
#           - SEC61G ENSDARG00000018637
#           - NAGA ENSDARG00000099313
#           - G0S2 ENSDARG00000078859
#           - HSP90AA1.2 ENSDARG00000024746
#           - PPIAB ENSDARG00000103994
#           - SRGN ENSDARG00000077069
#           - ITGB2 ENSDARG00000016939
#           - CTSC ENSDARG00000101334
#           - NKL.1 ENSDARG00000058673
#           - LAMTOR4 ENSDARG00000045542
#           - RPS25 ENSDARG00000041811
#           - RAB5AA ENSDARG00000018602
#           - VASPB ENSDARG00000017105
#           - RPS4X ENSDARG00000014690
#           - SI:CH1073-67J19.1 ENSDARG00000105096
#           - UCP2 ENSDARG00000043154
#       - name: Leydig cell
#         markers:
#           - LYZ ENSDARG00000057789
#           - LECT2L ENSDARG00000033227
#           - ICN ENSDARG00000009978
#           - BX908782.2 ENSDARG00000101479
#           - PFN1 ENSDARG00000088091
#           - TMSB4X ENSDARG00000077777
#           - NPSN ENSDARG00000010423
#           - SI:CH1073-67J19.1 ENSDARG00000105096
#           - CEBPB ENSDARG00000042725
#           - TMSB1 ENSDARG00000104181
#           - COTL1 ENSDARG00000026829
#           - ARPC1B ENSDARG00000027063
#           - ACTB2 ENSDARG00000037870
#           - LAPTM5 ENSDARG00000101785
#           - CR383676.1 ENSDARG00000099859
#           - CXCR4B ENSDARG00000041959
#           - STAR ENSDARG00000006137
#           - GSDF ENSDARG00000075301
#           - ARHGDIG ENSDARG00000004034
#           - HSP70.1 ENSDARG00000029688
#           - FCER1GL ENSDARG00000104077
#           - PTMAB ENSDARG00000101766
#           - HSP70L ENSDARG00000055723
#           - NCCRP1 ENSDARG00000035326
#           - SI:CH211-9D9.1 ENSDARG00000099839
#           - CORO1A ENSDARG00000054610
#           - MCL1A ENSDARG00000009779
#           - CR318588.4 ENSDARG00000095556
#           - PONZR1 ENSDARG00000090444
#           - ICN2 ENSDARG00000055514
#           - HSP70.2 ENSDARG00000092362
#           - S100A10B ENSDARG00000025254
#           - CD63 ENSDARG00000025147
#           - COX6B1 ENSDARG00000045230
#           - ZGC:64051 ENSDARG00000068233
#           - ACTB1 ENSDARG00000037746
#           - CFL1 ENSDARG00000021124
#           - NR4A1 ENSDARG00000000796
#           - HSP70.3 ENSDARG00000021924
#           - DNAJB1B ENSDARG00000041394
#           - CYP11C1 ENSDARG00000042014
#           - WASB ENSDARG00000026350
#           - CD74A ENSDARG00000009087
#           - CKBB ENSDARG00000043257
#           - UBB ENSDARG00000093313
#           - BHLHE40 ENSDARG00000004060
#           - ALDOAA ENSDARG00000011665
#           - SRGN ENSDARG00000077069
#           - NCF1 ENSDARG00000033735
#           - NFKBIAB ENSDARG00000007693
#           - B2M ENSDARG00000053136
#           - TUBA8L ENSDARG00000042708
#           - RACK1 ENSDARG00000041619
#           - HSP90AA1.2 ENSDARG00000024746
#           - CD74B ENSDARG00000036628
#           - EEF1A1L1 ENSDARG00000020850
#           - SLA2 ENSDARG00000020788
#           - ZFP36L1B ENSDARG00000021443
#           - HMGN6 ENSDARG00000087636
#           - F3B ENSDARG00000005673
#           - RPL7A ENSDARG00000019230
#           - PPDPFA ENSDARG00000007682
#           - MHC2DAB ENSDARG00000079105
#           - IER2A ENSDARG00000099195
#           - RPS6 ENSDARG00000019778
#           - FO203432.1 ENSDARG00000115195
#           - ZGC:110239 ENSDARG00000077664
#           - RPS4X ENSDARG00000014690
#           - RPL10A ENSDARG00000042905
#           - RPL8 ENSDARG00000014867
#           - RPL13A ENSDARG00000044093
#           - RPL3 ENSDARG00000003599
#           - RPS18 ENSDARG00000100392
#           - FDX1B ENSDARG00000038956
#           - RPL18 ENSDARG00000029533
#           - RPS11 ENSDARG00000053058
#           - RPL18A ENSDARG00000025073
#           - ATF3 ENSDARG00000007823
#           - RPL30 ENSDARG00000035871
#           - PDE9A ENSDARG00000060280
#           - RPS27A ENSDARG00000032725
#       - name: Innate immune cell
#         markers:
#           - SI:DKEYP-75B4.10 ENSDARG00000079043
#           - SI:DKEY-203A12.2 ENSDARG00000102271
#           - SI:DKEY-203A12.9 ENSDARG00000104721
#           - CABZ01058647.1 ENSDARG00000117107
#           - BX322787.1 ENSDARG00000105779
#           - SI:DKEY-203A12.5 ENSDARG00000099673
#           - SI:CH211-14A17.10 ENSDARG00000076534
#           - CST14B.2 ENSDARG00000112540
#           - SI:CH211-214P16.1 ENSDARG00000044129
#           - CCL34B.9 ENSDARG00000078205
#           - ITLN1 ENSDARG00000095082
#           - SI:CH1073-110A20.2 ENSDARG00000092806
#           - SI:DKEY-203A12.7 ENSDARG00000099811
#           - SI:DKEY-77G12.4 ENSDARG00000103336
#           - PFN1 ENSDARG00000088091
#           - C3A.4 ENSDARG00000093198
#           - ACTB2 ENSDARG00000037870
#           - ICN ENSDARG00000009978
#           - CORO1A ENSDARG00000054610
#           - TMSB4X ENSDARG00000077777
#           - CR383676.1 ENSDARG00000099859
#           - HSP70.3 ENSDARG00000021924
#           - HSP70L ENSDARG00000055723
#           - NME2B.1 ENSDARG00000103791
#           - CR318588.4 ENSDARG00000095556
#           - HMGN6 ENSDARG00000087636
#           - RPL17 ENSDARG00000057556
#           - CD74B ENSDARG00000036628
#           - EEF1A1L1 ENSDARG00000020850
#           - MACO1B ENSDARG00000012741
#           - RPL21 ENSDARG00000010516
#           - SI:CH211-5K11.8 ENSDARG00000079078
#           - ALDOAA ENSDARG00000011665
#           - PGLS ENSDARG00000021233
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# Marker list saved:
# /mnt/workspace_stud/allstud/wp2/annotate_by_marker_and_features-sort/lists/zebrafish_gene_cellType_1708882982698910.yaml

# %% [markdown]
# ## 7. Validation

# %% [markdown]
# Check whether the format of the yaml file is correct.

# %%
if validate.validate_file(utils.read_in_yaml(f"{list_path}", marker_list=False), repo_path=repo_path):
    print(f"No errors were found concerning the '{LIST_NAME}' marker list.")
# Out:
# No errors were found concerning the 'zebrafish_gene_cellType' marker list.
