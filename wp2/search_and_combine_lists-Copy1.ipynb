# %% [markdown]
# # Marker Repo - search and combine lists

# %% [markdown]
# This notebook explains how to search the marker repository to further process and use a selection of lists. This happens mainly by selecting, combining, formatting and finally exporting the selection made. Wrapper functions facilitate this process and perform all four steps sequentially after a function call.

# %% [markdown]
# ## 1. Loading packages

# %%
import markerrepo.marker_repo as mr
import markerrepo.wrappers as wrap

# %load_ext autoreload
# %autoreload 2
# Out:
# /home/stud3/.conda/envs/marker-sort/lib/python3.11/site-packages/markerrepo/wrappers.py:20: RuntimeWarning: Please install the latest sctoolbox version. Some functionality may not be available.
#   warnings.warn("Please install the latest sctoolbox version. Some functionality may not be available.", RuntimeWarning)

# %% [markdown]
# ## Settings

# %% [markdown]
# Specify path of the cloned repository.

# %%
repo_path = "/mnt/workspace_stud/allstud/wp2/annotate_by_marker_and_features-sort"

# %% [markdown]
# ## 2. Search database and combine selected lists

# %% [markdown]
# By using the <b>Guided Search</b>, a selection of marker lists can be compiled to suit the individual needs. First, a column of the available metadata of all lists is selected to search in it afterwards. This process can be repeated as often as you like until you have exactly the lists you need in the selection. Finally, the selection can be returned as metadata or as a finished marker list in the form of a DataFrame.

# %% [markdown]
# Return search results as metadata DataFrame.

# %%
results = mr.guided_search(repo_path=repo_path, out="metadata")
display(results)
# Out:
# Available columns for search:
# 1: ID
# 2: List name
# 3: Organism name
# 4: Taxonomy ID
# 5: Marker type
# 6: Submitter name
# 7: List type
# 8: Date
# 9: Source
# 10: tags_transferred
# n: Next page
# Enter identifier of column to search in (leave blank to search in all columns): 6
# Do you want to see all unique entries in this column? (yes/no) yes
# Unique entries:
# Kessler, Micha Frederick
# Quintanilla, Marta
# Bentsen, Mette
# Enter search terms (separated by commas, '-' for negative search): Quintanilla, Marta
# Perform an exact search? (yes/no): no
# Consider case sensitivity? (yes/no): no
# Number of results: 14
# Do you want to see the results? (yes/no): yes
#                   index                List name Organism name Taxonomy ID  \
# ID
# 170879528140527      13  zebrafish_gene_cellType     zebrafish        7955
# 1708791034778127    119  zebrafish_gene_cellType     zebrafish        7955
# 1708794021236062    120  zebrafish_gene_cellType     zebrafish        7955
# 1708794224393050    121  zebrafish_gene_cellType     zebrafish        7955
# 1708794292444744    122  zebrafish_gene_cellType     zebrafish        7955
# 1708794386648230    123  zebrafish_gene_cellType     zebrafish        7955
# 1708795042806779    124  zebrafish_gene_cellType     zebrafish        7955
# 1708795114842373    125  zebrafish_gene_cellType     zebrafish        7955
# 1708795181273162    126  zebrafish_gene_cellType     zebrafish        7955
# 1708795232256198    127  zebrafish_gene_cellType     zebrafish        7955
# 1708795334941388    128  zebrafish_gene_cellType     zebrafish        7955
# 1708795380513250    129  zebrafish_gene_cellType     zebrafish        7955
# 1708795433333565    130  zebrafish_gene_cellType     zebrafish        7955
# 1708795485542915    131  zebrafish_gene_cellType     zebrafish        7955
#
#                  Marker type      Submitter name List type        Date Source  \
# ID
# 170879528140527        Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708791034778127       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708794021236062       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708794224393050       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708794292444744       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708794386648230       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795042806779       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795114842373       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795181273162       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795232256198       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795334941388       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795380513250       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795433333565       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795485542915       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
#
#                  tags_transferred Email Tissue  \
# ID
# 170879528140527               NaN   NaN    NaN
# 1708791034778127              NaN   NaN    NaN
# 1708794021236062              NaN   NaN    NaN
# 1708794224393050              NaN   NaN    NaN
# 1708794292444744              NaN   NaN    NaN
# 1708794386648230              NaN   NaN    NaN
# 1708795042806779              NaN   NaN    NaN
# 1708795114842373              NaN   NaN    NaN
# 1708795181273162              NaN   NaN    NaN
# 1708795232256198              NaN   NaN    NaN
# 1708795334941388              NaN   NaN    NaN
# 1708795380513250              NaN   NaN    NaN
# 1708795433333565              NaN   NaN    NaN
# 1708795485542915              NaN   NaN    NaN
#
#                                                              Marker  \
# ID
# 170879528140527   [CD83, ENSDARG00000079553, SH3BP5B, ENSDARG000...
# 1708791034778127  [CRIP1, ENSDARG00000053858, COX5B, ENSDARG0000...
# 1708794021236062  [CRIP1, ENSDARG00000053858, COX5B, ENSDARG0000...
# 1708794224393050  [PSMB9A, ENSDARG00000000656, TMCO1, ENSDARG000...
# 1708794292444744  [CISD2, ENSDARG00000052703, GCDHA, ENSDARG0000...
# 1708794386648230  [SLC38A4, ENSDARG00000018149, SI:CH211-117L17....
# 1708795042806779  [CD83, ENSDARG00000079553, AMY2A, ENSDARG00000...
# 1708795114842373  [ARPC3, ENSDARG00000057882, ALDH9A1A.1, ENSDAR...
# 1708795181273162  [PSMB9A, ENSDARG00000000656, CD83, ENSDARG0000...
# 1708795232256198  [GCDHA, ENSDARG00000037057, SPICE1, ENSDARG000...
# 1708795334941388  [SMARCC1A, ENSDARG00000017397, CD83, ENSDARG00...
# 1708795380513250  [CD83, ENSDARG00000079553, ARPC3, ENSDARG00000...
# 1708795433333565  [CD83, ENSDARG00000079553, SI:CH211-178N15.1, ...
# 1708795485542915  [PSMB9A, ENSDARG00000000656, SUMO1, ENSDARG000...
#
#                                                                Info
# ID
# 170879528140527   [Oocyte_ca15b high, Macrophage, Oocyte_h2af1al...
# 1708791034778127  [Filament ionocyte, NCC ionocyte, Proliferatin...
# 1708794021236062  [Filament ionocyte, NCC ionocyte, Proliferatin...
# 1708794224393050  [Macrophage, B cell, Thrombocyte, Macrophage_g...
# 1708794292444744  [Macrophage_grn1 high, Macrophage, Radial glia...
# 1708794386648230  [Macrophage, Retinal cone cell, Stromal cell, ...
# 1708795042806779  [Pancreas endocrine cells , Macrophage, Intest...
# 1708795114842373  [Proliferating cell, Macrophage, Nephron epith...
# 1708795181273162  [Macrophage, Hepatocyte, Biliary epithelial ce...
# 1708795232256198  [Epithelial cell_aqp3a high, Skeletal muscle c...
# 1708795334941388  [Proliferating cell, Macrophage, Fat cell, Str...
# 1708795380513250  [Proliferating cell, Macrophage, B cell, Macro...
# 1708795433333565  [Proliferating cell, Macrophage, Stromal cell_...
# 1708795485542915  [Macrophage, Leydig cell, Spermatogonia, Sperm...
# Do you want to continue searching? (yes/no): no
#                   index                List name Organism name Taxonomy ID  \
# ID
# 170879528140527      13  zebrafish_gene_cellType     zebrafish        7955
# 1708791034778127    119  zebrafish_gene_cellType     zebrafish        7955
# 1708794021236062    120  zebrafish_gene_cellType     zebrafish        7955
# 1708794224393050    121  zebrafish_gene_cellType     zebrafish        7955
# 1708794292444744    122  zebrafish_gene_cellType     zebrafish        7955
# 1708794386648230    123  zebrafish_gene_cellType     zebrafish        7955
# 1708795042806779    124  zebrafish_gene_cellType     zebrafish        7955
# 1708795114842373    125  zebrafish_gene_cellType     zebrafish        7955
# 1708795181273162    126  zebrafish_gene_cellType     zebrafish        7955
# 1708795232256198    127  zebrafish_gene_cellType     zebrafish        7955
# 1708795334941388    128  zebrafish_gene_cellType     zebrafish        7955
# 1708795380513250    129  zebrafish_gene_cellType     zebrafish        7955
# 1708795433333565    130  zebrafish_gene_cellType     zebrafish        7955
# 1708795485542915    131  zebrafish_gene_cellType     zebrafish        7955
#
#                  Marker type      Submitter name List type        Date Source  \
# ID
# 170879528140527        Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708791034778127       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708794021236062       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708794224393050       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708794292444744       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708794386648230       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795042806779       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795114842373       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795181273162       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795232256198       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795334941388       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795380513250       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795433333565       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795485542915       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
#
#                  tags_transferred Email Tissue  \
# ID
# 170879528140527               NaN   NaN    NaN
# 1708791034778127              NaN   NaN    NaN
# 1708794021236062              NaN   NaN    NaN
# 1708794224393050              NaN   NaN    NaN
# 1708794292444744              NaN   NaN    NaN
# 1708794386648230              NaN   NaN    NaN
# 1708795042806779              NaN   NaN    NaN
# 1708795114842373              NaN   NaN    NaN
# 1708795181273162              NaN   NaN    NaN
# 1708795232256198              NaN   NaN    NaN
# 1708795334941388              NaN   NaN    NaN
# 1708795380513250              NaN   NaN    NaN
# 1708795433333565              NaN   NaN    NaN
# 1708795485542915              NaN   NaN    NaN
#
#                                                              Marker  \
# ID
# 170879528140527   [CD83, ENSDARG00000079553, SH3BP5B, ENSDARG000...
# 1708791034778127  [CRIP1, ENSDARG00000053858, COX5B, ENSDARG0000...
# 1708794021236062  [CRIP1, ENSDARG00000053858, COX5B, ENSDARG0000...
# 1708794224393050  [PSMB9A, ENSDARG00000000656, TMCO1, ENSDARG000...
# 1708794292444744  [CISD2, ENSDARG00000052703, GCDHA, ENSDARG0000...
# 1708794386648230  [SLC38A4, ENSDARG00000018149, SI:CH211-117L17....
# 1708795042806779  [CD83, ENSDARG00000079553, AMY2A, ENSDARG00000...
# 1708795114842373  [ARPC3, ENSDARG00000057882, ALDH9A1A.1, ENSDAR...
# 1708795181273162  [PSMB9A, ENSDARG00000000656, CD83, ENSDARG0000...
# 1708795232256198  [GCDHA, ENSDARG00000037057, SPICE1, ENSDARG000...
# 1708795334941388  [SMARCC1A, ENSDARG00000017397, CD83, ENSDARG00...
# 1708795380513250  [CD83, ENSDARG00000079553, ARPC3, ENSDARG00000...
# 1708795433333565  [CD83, ENSDARG00000079553, SI:CH211-178N15.1, ...
# 1708795485542915  [PSMB9A, ENSDARG00000000656, SUMO1, ENSDARG000...
#
#                                                                Info
# ID
# 170879528140527   [Oocyte_ca15b high, Macrophage, Oocyte_h2af1al...
# 1708791034778127  [Filament ionocyte, NCC ionocyte, Proliferatin...
# 1708794021236062  [Filament ionocyte, NCC ionocyte, Proliferatin...
# 1708794224393050  [Macrophage, B cell, Thrombocyte, Macrophage_g...
# 1708794292444744  [Macrophage_grn1 high, Macrophage, Radial glia...
# 1708794386648230  [Macrophage, Retinal cone cell, Stromal cell, ...
# 1708795042806779  [Pancreas endocrine cells , Macrophage, Intest...
# 1708795114842373  [Proliferating cell, Macrophage, Nephron epith...
# 1708795181273162  [Macrophage, Hepatocyte, Biliary epithelial ce...
# 1708795232256198  [Epithelial cell_aqp3a high, Skeletal muscle c...
# 1708795334941388  [Proliferating cell, Macrophage, Fat cell, Str...
# 1708795380513250  [Proliferating cell, Macrophage, B cell, Macro...
# 1708795433333565  [Proliferating cell, Macrophage, Stromal cell_...
# 1708795485542915  [Macrophage, Leydig cell, Spermatogonia, Sperm...

# %% [markdown]
# Return search results as marker list DataFrame.

# %%
results = mr.guided_search(repo_path=repo_path, out="marker_list")
display(results)
# Out:
# Available columns for search:
# 1: ID
# 2: List name
# 3: Organism name
# 4: Taxonomy ID
# 5: Marker type
# 6: Submitter name
# 7: List type
# 8: Date
# 9: Source
# 10: tags_transferred
# n: Next page
# Enter identifier of column to search in (leave blank to search in all columns): 6
# Do you want to see all unique entries in this column? (yes/no) yes
# Unique entries:
# Kessler, Micha Frederick
# Quintanilla, Marta
# Bentsen, Mette
# Enter search terms (separated by commas, '-' for negative search): Quintanilla, Marta
# Perform an exact search? (yes/no): no
# Consider case sensitivity? (yes/no): no
# Number of results: 14
# Do you want to see the results? (yes/no): yes
#                   index                List name Organism name Taxonomy ID  \
# ID
# 170879528140527      13  zebrafish_gene_cellType     zebrafish        7955
# 1708791034778127    119  zebrafish_gene_cellType     zebrafish        7955
# 1708794021236062    120  zebrafish_gene_cellType     zebrafish        7955
# 1708794224393050    121  zebrafish_gene_cellType     zebrafish        7955
# 1708794292444744    122  zebrafish_gene_cellType     zebrafish        7955
# 1708794386648230    123  zebrafish_gene_cellType     zebrafish        7955
# 1708795042806779    124  zebrafish_gene_cellType     zebrafish        7955
# 1708795114842373    125  zebrafish_gene_cellType     zebrafish        7955
# 1708795181273162    126  zebrafish_gene_cellType     zebrafish        7955
# 1708795232256198    127  zebrafish_gene_cellType     zebrafish        7955
# 1708795334941388    128  zebrafish_gene_cellType     zebrafish        7955
# 1708795380513250    129  zebrafish_gene_cellType     zebrafish        7955
# 1708795433333565    130  zebrafish_gene_cellType     zebrafish        7955
# 1708795485542915    131  zebrafish_gene_cellType     zebrafish        7955
#
#                  Marker type      Submitter name List type        Date Source  \
# ID
# 170879528140527        Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708791034778127       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708794021236062       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708794224393050       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708794292444744       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708794386648230       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795042806779       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795114842373       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795181273162       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795232256198       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795334941388       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795380513250       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795433333565       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
# 1708795485542915       Genes  Quintanilla, Marta       NaN  24.02.2024    NaN
#
#                  tags_transferred Email Tissue  \
# ID
# 170879528140527               NaN   NaN    NaN
# 1708791034778127              NaN   NaN    NaN
# 1708794021236062              NaN   NaN    NaN
# 1708794224393050              NaN   NaN    NaN
# 1708794292444744              NaN   NaN    NaN
# 1708794386648230              NaN   NaN    NaN
# 1708795042806779              NaN   NaN    NaN
# 1708795114842373              NaN   NaN    NaN
# 1708795181273162              NaN   NaN    NaN
# 1708795232256198              NaN   NaN    NaN
# 1708795334941388              NaN   NaN    NaN
# 1708795380513250              NaN   NaN    NaN
# 1708795433333565              NaN   NaN    NaN
# 1708795485542915              NaN   NaN    NaN
#
#                                                              Marker  \
# ID
# 170879528140527   [CD83, ENSDARG00000079553, SH3BP5B, ENSDARG000...
# 1708791034778127  [CRIP1, ENSDARG00000053858, COX5B, ENSDARG0000...
# 1708794021236062  [CRIP1, ENSDARG00000053858, COX5B, ENSDARG0000...
# 1708794224393050  [PSMB9A, ENSDARG00000000656, TMCO1, ENSDARG000...
# 1708794292444744  [CISD2, ENSDARG00000052703, GCDHA, ENSDARG0000...
# 1708794386648230  [SLC38A4, ENSDARG00000018149, SI:CH211-117L17....
# 1708795042806779  [CD83, ENSDARG00000079553, AMY2A, ENSDARG00000...
# 1708795114842373  [ARPC3, ENSDARG00000057882, ALDH9A1A.1, ENSDAR...
# 1708795181273162  [PSMB9A, ENSDARG00000000656, CD83, ENSDARG0000...
# 1708795232256198  [GCDHA, ENSDARG00000037057, SPICE1, ENSDARG000...
# 1708795334941388  [SMARCC1A, ENSDARG00000017397, CD83, ENSDARG00...
# 1708795380513250  [CD83, ENSDARG00000079553, ARPC3, ENSDARG00000...
# 1708795433333565  [CD83, ENSDARG00000079553, SI:CH211-178N15.1, ...
# 1708795485542915  [PSMB9A, ENSDARG00000000656, SUMO1, ENSDARG000...
#
#                                                                Info
# ID
# 170879528140527   [Oocyte_ca15b high, Macrophage, Oocyte_h2af1al...
# 1708791034778127  [Filament ionocyte, NCC ionocyte, Proliferatin...
# 1708794021236062  [Filament ionocyte, NCC ionocyte, Proliferatin...
# 1708794224393050  [Macrophage, B cell, Thrombocyte, Macrophage_g...
# 1708794292444744  [Macrophage_grn1 high, Macrophage, Radial glia...
# 1708794386648230  [Macrophage, Retinal cone cell, Stromal cell, ...
# 1708795042806779  [Pancreas endocrine cells , Macrophage, Intest...
# 1708795114842373  [Proliferating cell, Macrophage, Nephron epith...
# 1708795181273162  [Macrophage, Hepatocyte, Biliary epithelial ce...
# 1708795232256198  [Epithelial cell_aqp3a high, Skeletal muscle c...
# 1708795334941388  [Proliferating cell, Macrophage, Fat cell, Str...
# 1708795380513250  [Proliferating cell, Macrophage, B cell, Macro...
# 1708795433333565  [Proliferating cell, Macrophage, Stromal cell_...
# 1708795485542915  [Macrophage, Leydig cell, Spermatogonia, Sperm...
# Do you want to continue searching? (yes/no): no
#                                      Marker               Info
# 0                 MUC5.2 ENSDARG00000058556        Mucous cell
# 1                  HBBA1 ENSDARG00000097238        Mucous cell
# 2                 PVALB8 ENSDARG00000037790        Mucous cell
# 3        SI:CH211-5K11.8 ENSDARG00000079078        Mucous cell
# 4      SI:CH211-125E6.11 ENSDARG00000025783        Mucous cell
# ...                                     ...                ...
# 20997               SAGA ENSDARG00000012610  Retinal cone cell
# 20998              PDE6A ENSDARG00000000380  Retinal cone cell
# 20999               MTBL ENSDARG00000102051  Retinal cone cell
# 21000   SI:CH73-281N10.2 ENSDARG00000097102  Retinal cone cell
# 21001              HACD2 ENSDARG00000014806  Retinal cone cell
#
# [16990 rows x 2 columns]

# %% [markdown]
# Export the combined marker list using Gene Symbols as identifiers.

# %%
mr.export_marker_list(results, file_name="Combined", marker_id="symbol")
# Out:
# Folder /mnt/workspace_stud/stud3/annotate_by_marker_and_features-sorting/annotate_by_marker_and_features/notebooks/exported_lists created.
# Marker list saved: /mnt/workspace_stud/stud3/annotate_by_marker_and_features-sorting/annotate_by_marker_and_features/notebooks/exported_lists/Combined
# '/mnt/workspace_stud/stud3/annotate_by_marker_and_features-sorting/annotate_by_marker_and_features/notebooks/exported_lists/Combined'

# %% [markdown]
# Export the combined marker list using Ensembl IDs as identifiers.

# %%
mr.export_marker_list(results, file_name="Combined", marker_id="ensembl")
# Out:
# Marker list saved: /mnt/workspace_stud/stud3/annotate_by_marker_and_features-sorting/annotate_by_marker_and_features/notebooks/exported_lists/Combined_20240224190350
# '/mnt/workspace_stud/stud3/annotate_by_marker_and_features-sorting/annotate_by_marker_and_features/notebooks/exported_lists/Combined_20240224190350'

# %% [markdown]
# ## 3. Wrapper functions

# %% [markdown]
# <b>Use the guided search to create a new marker list in "two column" style.</b><br>
# <br>This format can be used for custom cell type annotations via SCSA, for example. The function combines, formats and exports the new marker list accordingly. It returns the path of the created file. You can adjust the file name by using the "file_name" parameter.

# %% [markdown]
# Get Gene Symbols

# %%
wrap.convert_markers(repo_path=repo_path, gs=True, style="two_column", file_name="Gene_symbols")

# %% [markdown]
# Get Ensembl IDs

# %%
wrap.convert_markers(repo_path=repo_path, gs=True, style="two_column", file_name="Ensembl_IDs", ensembl=True)

# %% [markdown]
# <b>Use the guided search to create a new marker list in "score" style.</b><br>
# <br>
# When you choose this function, the output is formatted into a three-column layout: the first column for the marker name, the second for the cell type it's associated with, and the third for the weight or score assigned to each marker.

# %%
wrap.convert_markers(repo_path=repo_path, gs=True, style="score", path=".", file_name="mouse_panglao", organism="Mm")
