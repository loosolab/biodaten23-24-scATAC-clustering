# %% [markdown]
# # Students Project 2023/24
#
# ## Workproject Clustering Validation

# %% [markdown]
# ## 1. Define the paths and args
# Set the arguments and paths to execute the pipeline.

# %%
## Arguments

# n_neighbors
n_neighbors=15
neighbor_method='umap'
neighbor_metric='euclidean'

# UMAP
umap_spread=2.5
umap_min_dist=0.1

# Plot embedding
color='total_counts'

# Feel free to extent this with arguments needed downstream

# Filepaths:

h5ad_esophagus = "/mnt/workspace_stud/mbentse/catlas_objects/esophagus_muscularis_SM-A8CPH.h5ad"
h5ad_heart = "/mnt/workspace_stud/mbentse/catlas_objects/heart_lv_SM-IOBHO.h5ad"
h5ad_cerebellum = "/mnt/workspace_stud/mbentse/catlas_objects/cerebellum_sample_58.h5ad"
h5ad_nerve_tibial = "/mnt/workspace_stud/mbentse/catlas_objects/nerve_tibial_SM-CHLWU.h5ad"

# %% [markdown]
# ## 2. Imports

# %%
# Import packages
import episcanpy as epi
import scanpy as sc
import numpy as np
import datetime
import matplotlib.pyplot as plt
from importlib import reload
import time
import anndata as ad

from utils import load_metadata
import ari_optimizer
reload(ari_optimizer)
import pca_optimizer
reload(pca_optimizer)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import anndata as ad
import pandas as pd

# %% [markdown]
# ### Read in Metadata

# %%
#cell_metadata = "/home/stud2/Cell_metadata.tsv"
esophagus_muscularis_metadata = "/mnt/workspace_stud/allstud/wp1/data/catlas_metadata/esophagus_muscularis_metadata.tsv"
heart_metadata = "/mnt/workspace_stud/allstud/wp1/data/catlas_metadata/heart_lv_SM-IOBHO_metadata.tsv"
cerebellum_metadata = "/mnt/workspace_stud/allstud/wp1/data/catlas_metadata/cerebellum_sample_58_metadata.tsv"
nerve_tibial_metadata = "/mnt/workspace_stud/allstud/wp1/data/catlas_metadata/nerve_tibial_SM-CHLWU_metadata.tsv"
#---
metadata_list = [esophagus_muscularis_metadata, heart_metadata, cerebellum_metadata, nerve_tibial_metadata]

concatenated_df = pd.DataFrame()

# Iterate through each TSV file and concatenate its contents
for tsv_file in metadata_list:
    # Assuming your TSV files have a header, if not, set header=None
    df = pd.read_csv(tsv_file, sep='\t')
    
    # Concatenate along the rows (axis=0)
    concatenated_df = pd.concat([concatenated_df, df], axis=0, ignore_index=True)

# Save the concatenated DataFrame to a new TSV file
concatenated_df.to_csv('/mnt/workspace_stud/allstud/wp1/data/catlas_metadata/4tissue_metadata.tsv', sep='\t', index=False)

tissue4_metadata = '/mnt/workspace_stud/allstud/wp1/data/catlas_metadata/4tissue_metadata.tsv'

# %% [markdown]
# ## 3. Read h5ad files and build anndata objects

# %%
# %%time
adata_esophagus = epi.read_h5ad(h5ad_esophagus)
adata_heart = epi.read_h5ad(h5ad_heart)
adata_cerebellum = epi.read_h5ad(h5ad_cerebellum)
adata_nerve_tibial = epi.read_h5ad(h5ad_nerve_tibial)

adata = ad.concat([adata_esophagus, adata_heart, adata_cerebellum, adata_nerve_tibial], axis=0)

#adata = adata_heart.copy()
#adata = adata_cerebellum.copy()
#adata = adata_nerve_tibial.copy()
# Out:
# CPU times: user 4.63 s, sys: 2.07 s, total: 6.7 s
# Wall time: 8.04 s

# %%
adata.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [esophagus_muscularis_SM-A8CPH_1+AAGCTATACCGCTTCTCACAAG, esophagus_muscularis_SM-A8CPH_1+AATTCGGATGAAATGCTACGGG, esophagus_muscularis_SM-A8CPH_1+ACTGCACAGAGTCCAGATTTCC, esophagus_muscularis_SM-A8CPH_1+AGGTCACTGAGCTTACAATCGT, esophagus_muscularis_SM-A8CPH_1+AGTCGGAACGCCCAAGATCGAC, esophagus_muscularis_SM-A8CPH_1+AGTCGGAACGCCTGGGTTAATC, esophagus_muscularis_SM-A8CPH_1+ATAGCCCGGTACATCTAAGGAG, esophagus_muscularis_SM-A8CPH_1+ATCGATACGTGGACCGACAATG, esophagus_muscularis_SM-A8CPH_1+CACAGAGTCCCGTCCCTAGAAC, esophagus_muscularis_SM-A8CPH_1+CCAGGTCGTATCCCTAACCATA, esophagus_muscularis_SM-A8CPH_1+CCATCTGGCATGACACTGTGCG, esophagus_muscularis_SM-A8CPH_1+GACCTAAGGAGGATAAAGGGAT, esophagus_muscularis_SM-A8CPH_1+GCGGTGTATGAGTCCTGGTACT, esophagus_muscularis_SM-A8CPH_1+TACATCGTGAAGTGCCTAACAA, esophagus_muscularis_SM-A8CPH_1+TCTACTGGTAAAGCTCTCTGAT, esophagus_muscularis_SM-A8CPH_1+TTACCGAACCAACTAACGTCGA, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGACAGCGTCACTA, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGACCCACAGCAGT, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGACTTGAGTCATC, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGAGGCATGCAGAG, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGATAACCCGCTAA, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGATCATTGAGGCT, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGCAAACAAGAAGG, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGCACCATGCCATT, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGCACCGAAGGTCA, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGCATACCCGGTTC, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGCCGGATCAAGTT, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGCGAAGATCACTC, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGCGCTGAGCCAAT, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGCGTACTTCCTCG, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGGATGAACATGTC, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGGGTGTTCCCTAC, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGGTCAGTAGTCTG, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGGTGAAGCTTATG, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGGTTGTACGAGCC, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGTACAGCGCCGTT, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGTAGATCTGCCAA, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGTAGTTGGTTGGA, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGTATACGAACCCG, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGTGACTATTTCCC, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGTGCTGAGTTCCT, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGTTAGTGCTAGCA, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGTTCGGTTCCCAC, esophagus_muscularis_SM-A8CPH_1+AAACTACCAGTTGTCCTCGACG, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCAAAGCCCATTGCC, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCAACATCCGGTCTC, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCAACCACGAAGGGA, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCAACCACTATTCAC, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCAAGTGTCGGGTTG, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCAATAGGTGGTACC, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCAATGTGCATCTGG, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCAATTCATTTCCGC, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCAATTGGACTTAGC, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCACAGATCGAGGGA, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCACATCCTCATCAA, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCACCCTGGCAGTAT, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCACCGGTACATTCC, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCACCGTGAAAGACC, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCACGATTTCACCGA, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCACGTCGTGAAATT, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCACGTTCGTTTATG, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCACTAATTTGTGGG, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCACTGAAGATGTGC, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCACTGCTGGGTTCA, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCACTTGCTGCCTAT, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCAGACGGAGAACCT, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCAGACGTCCCTCAT, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCAGAGGGTGATTGC, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCAGCTGGTAGATAA, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCAGGAACGGTCTCA, esophagus_muscularis_SM-A8CPH_1+AACTGCGCCAGGAACGTCAGTT, esophagus_muscul ...
#
# [25943 rows x 0 columns]

# %% [markdown]
# ## 4. Read Metadata

# %%
# %%time
# Example: ['cellID', 'logUMI', 'tsse', 'tissue', 'cell type', 'Life stage']
columns_to_keep = ['cell type']
load_metadata(adata, tissue4_metadata, columns_to_keep=columns_to_keep)
# Out:
# CPU times: user 130 ms, sys: 6.78 ms, total: 137 ms
# Wall time: 152 ms

# %%
# add ontology metadata
ontology_path = f"/mnt/workspace_stud/allstud/wp1/data//Cell_ontology.tsv"
ontology_df = pd.read_csv(ontology_path, delimiter="\t")
ontology_df = ontology_df.rename(columns={
    "Cell type": "cell type", 
    "closest Cell Ontology term(s)": "ontology label",
    "Cell Ontology ID": "ontology id"})
adata.obs = pd.merge(adata.obs, ontology_df, how="left", on="cell type")

# %%
# only keep labels that are bigger than 1% of cell count
threshold = len(adata.obs["ontology label"]) / 100.0
counts = adata.obs["ontology label"].value_counts()
valid_labels = counts[counts >= threshold].index
adata = adata[adata.obs["ontology label"].isin(valid_labels)].copy()
# Out:
#  ImplicitModificationWarning:/home/stud2/.conda/envs/datenanalyse/lib/python3.10/site-packages/anndata/_core/anndata.py:183: Transforming to str index.

# %% [markdown]
# ## 5. Add metrics

# %%
# compute metrics
sc.pp.calculate_qc_metrics(adata=adata, percent_top=None, inplace=True)

# %% [markdown]
# ## 6. Normalize adata

# %%
sc.pp.normalize_total(adata, exclude_highly_expressed=False, target_sum=None)
sc.pp.log1p(adata)

# %% [markdown]
# ## 7. Ajusting Parameters

# %%
# %%capture testing_function
max_op_louvain_ari, max_op_louvain_ncomp, max_op_louvain_res, \
max_op_leiden_ari, max_op_leiden_ncomp, max_op_leiden_res, \
max_op_kmeans_ari, max_op_kmeans_ncomp, max_op_kmeans_kclust, \
op_louvain_ari_dict, \
op_leiden_ari_dict, \
op_kmeans_ari_dict, \
= pca_optimizer.pca_optimizer_m1(adata, 1, 50)

print("<>"*20)
print(f'"Best" Optimized ARI-louvain:\t{max_op_louvain_ari}\tn_comps:{max_op_louvain_ncomp}\tres:{max_op_louvain_res}')
print(f'"Best" Optimized ARI-leiden:\t{max_op_leiden_ari}\tn_comps:{max_op_leiden_ncomp}\tres:{max_op_leiden_res}')
print(f'"Best" Optimized ARI-kmeans:\t{max_op_kmeans_ari}\tn_comps:{max_op_kmeans_ncomp}\tk cluster:{max_op_kmeans_kclust}')
print("<>"*20)

# %%
testing_function.show()
# Out:
# ====================
# pca_comps:	 1
# Optimized ARI-louvain:	0.030508225055796156	(resolution:0.1)
# Optimized ARI-leiden:	0.01756833238907331	(resolution:0.1)
# Optimized ARI-kmeans:	0.09397246522820912	(clusters:3)
# ====================
# pca_comps:	 2
# Optimized ARI-louvain:	0.22109161297113591	(resolution:0.2)
# Optimized ARI-leiden:	0.21675741419424968	(resolution:0.1)
# Optimized ARI-kmeans:	0.20238565974829012	(clusters:4)
# ====================
# pca_comps:	 3
# Optimized ARI-louvain:	0.33810136640808763	(resolution:0.1)
# Optimized ARI-leiden:	0.3189778256434353	(resolution:0.1)
# Optimized ARI-kmeans:	0.27893401601409634	(clusters:5)
# ====================
# pca_comps:	 4
# Optimized ARI-louvain:	0.4430935294570918	(resolution:0.1)
# Optimized ARI-leiden:	0.462032417782947	(resolution:0.1)
# Optimized ARI-kmeans:	0.3498490482786114	(clusters:6)
# ====================
# pca_comps:	 5
# Optimized ARI-louvain:	0.5396975467723256	(resolution:0.2)
# Optimized ARI-leiden:	0.46761810635780043	(resolution:0.3)
# Optimized ARI-kmeans:	0.3847384107885747	(clusters:7)
# ====================
# pca_comps:	 6
# Optimized ARI-louvain:	0.5180697490938053	(resolution:0.3)
# Optimized ARI-leiden:	0.5850408923036208	(resolution:0.2)
# Optimized ARI-kmeans:	0.40936666762200574	(clusters:8)
# ====================
# pca_comps:	 7
# Optimized ARI-louvain:	0.5620498613592033	(resolution:0.3)
# Optimized ARI-leiden:	0.5417071172561622	(resolution:0.3)
# Optimized ARI-kmeans:	0.4454789512563987	(clusters:9)
# ====================
# pca_comps:	 8
# Optimized ARI-louvain:	0.6178996369216821	(resolution:0.4)
# Optimized ARI-leiden:	0.5659148538724444	(resolution:0.2)
# Optimized ARI-kmeans:	0.4326699772420487	(clusters:9)
# ====================
# pca_comps:	 9
# Optimized ARI-louvain:	0.6489474139676336	(resolution:0.3)
# Optimized ARI-leiden:	0.6454160476236948	(resolution:0.2)
# Optimized ARI-kmeans:	0.4878990145671925	(clusters:11)
# ====================
# pca_comps:	 10
# Optimized ARI-louvain:	0.7230790836852279	(resolution:0.2)
# Optimized ARI-leiden:	0.68359533066966	(resolution:0.3)
# Optimized ARI-kmeans:	0.5043051759520913	(clusters:11)
# ====================
# pca_comps:	 11
# Optimized ARI-louvain:	0.7226346859472049	(resolution:0.2)
# Optimized ARI-leiden:	0.689534361055157	(resolution:0.2)
# Optimized ARI-kmeans:	0.507584868319147	(clusters:11)
# ====================
# pca_comps:	 12
# Optimized ARI-louvain:	0.732542045953262	(resolution:0.2)
# Optimized ARI-leiden:	0.7439256331257034	(resolution:0.1)
# Optimized ARI-kmeans:	0.4964666461447036	(clusters:11)
# ====================
# pca_comps:	 13
# Optimized ARI-louvain:	0.7460255003681354	(resolution:0.2)
# Optimized ARI-leiden:	0.7464736707957099	(resolution:0.2)
# Optimized ARI-kmeans:	0.4974197292977213	(clusters:11)
# ====================
# pca_comps:	 14
# Optimized ARI-louvain:	0.7335173016912144	(resolution:0.2)
# Optimized ARI-leiden:	0.7464050110670287	(resolution:0.2)
# Optimized ARI-kmeans:	0.49688543324936346	(clusters:11)
# ====================
# pca_comps:	 15
# Optimized ARI-louvain:	0.738715289578979	(resolution:0.3)
# Optimized ARI-leiden:	0.7363970437496388	(resolution:0.2)
# Optimized ARI-kmeans:	0.5132751813030969	(clusters:12)
# ====================
# pca_comps:	 16
# Optimized ARI-louvain:	0.7410378765414195	(resolution:0.3)
# Optimized ARI-leiden:	0.7496404761136464	(resolution:0.3)
# Optimized ARI-kmeans:	0.5158723736072535	(clusters:11)
# ====================
# pca_comps:	 17
# Optimized ARI-louvain:	0.7373883013201529	(resolution:0.2)
# Optimized ARI-leiden:	0.7410614331173949	(resolution:0.2)
# Optimized ARI-kmeans:	0.521646966386011	(clusters:12)
# ====================
# pca_comps:	 18
# Optimized ARI-louvain:	0.7330571679822554	(resolution:0.5)
# Optimized ARI-leiden:	0.7465967696232189	(resolution:0.3)
# Optimized ARI-kmeans:	0.5165461375465278	(clusters:12)
# ====================
# pca_comps:	 19
# Optimized ARI-louvain:	0.7305872218162561	(resolution:0.3)
# Optimized ARI-leiden:	0.739635050025462	(resolution:0.2)
# Optimized ARI-kmeans:	0.45568496934647795	(clusters:14)
# ====================
# pca_comps:	 20
# Optimized ARI-louvain:	0.735991614547619	(resolution:0.5)
# Optimized ARI-leiden:	0.7292489102382916	(resolution:0.2)
# Optimized ARI-kmeans:	0.5418780011583396	(clusters:13)
# ====================
# pca_comps:	 21
# Optimized ARI-louvain:	0.7262756065579745	(resolution:0.6)
# Optimized ARI-leiden:	0.7358753480097153	(resolution:0.3)
# Optimized ARI-kmeans:	0.5348246199751767	(clusters:13)
# ====================
# pca_comps:	 22
# Optimized ARI-louvain:	0.7218404135554645	(resolution:0.4)
# Optimized ARI-leiden:	0.735707016657528	(resolution:0.3)
# Optimized ARI-kmeans:	0.5144158657978088	(clusters:15)
# ====================
# pca_comps:	 23
# Optimized ARI-louvain:	0.7308295472815083	(resolution:0.6)
# Optimized ARI-leiden:	0.7296104489882188	(resolution:0.4)
# Optimized ARI-kmeans:	0.5221275782014984	(clusters:12)
# ====================
# pca_comps:	 24
# Optimized ARI-louvain:	0.7310612161632535	(resolution:0.5)
# Optimized ARI-leiden:	0.7292381608772837	(resolution:0.4)
# Optimized ARI-kmeans:	0.45032956717044964	(clusters:14)
# ====================
# pca_comps:	 25
# Optimized ARI-louvain:	0.7298923433519395	(resolution:0.6)
# Optimized ARI-leiden:	0.717747965726101	(resolution:0.3)
# Optimized ARI-kmeans:	0.5150590831548341	(clusters:12)
# ====================
# pca_comps:	 26
# Optimized ARI-louvain:	0.7295757195698342	(resolution:0.6)
# Optimized ARI-leiden:	0.7155762157535327	(resolution:0.5)
# Optimized ARI-kmeans:	0.49768478293055135	(clusters:11)
# ====================
# pca_comps:	 27
# Optimized ARI-louvain:	0.7222404035095824	(resolution:0.6)
# Optimized ARI-leiden:	0.7288927539285006	(resolution:0.5)
# Optimized ARI-kmeans:	0.5147401665346244	(clusters:12)
# ====================
# pca_comps:	 28
# Optimized ARI-louvain:	0.7063352776570475	(resolution:0.4)
# Optimized ARI-leiden:	0.7227597642507132	(resolution:0.4)
# Optimized ARI-kmeans:	0.5144569726131447	(clusters:12)
# ====================
# pca_comps:	 29
# Optimized ARI-louvain:	0.7266791846262604	(resolution:0.6)
# Optimized ARI-leiden:	0.7237112860720367	(resolution:0.5)
# Optimized ARI-kmeans:	0.5362273647656172	(clusters:12)
# ====================
# pca_comps:	 30
# Optimized ARI-louvain:	0.7240691908085826	(resolution:0.6)
# Optimized ARI-leiden:	0.7210484037815071	(resolution:0.4)
# Optimized ARI-kmeans:	0.5087130729765417	(clusters:11)
# ====================
# pca_comps:	 31
# Optimized ARI-louvain:	0.7169742960018529	(resolution:0.5)
# Optimized ARI-leiden:	0.7219650530200582	(resolution:0.4)
# Optimized ARI-kmeans:	0.4997655030594451	(clusters:11)
# ====================
# pca_comps:	 32
# Optimized ARI-louvain:	0.7269771872853078	(resolution:0.7)
# Optimized ARI-leiden:	0.7276178055830391	(resolution:0.5)
# Optimized ARI-kmeans:	0.4788304980021759	(clusters:10)
# ====================
# pca_comps:	 33
# Optimized ARI-louvain:	0.7156469595015071	(resolution:0.6)
# Optimized ARI-leiden:	0.7190877046522569	(resolution:0.4)
# Optimized ARI-kmeans:	0.47938797781200615	(clusters:10)
# ====================
# pca_comps:	 34
# Optimized ARI-louvain:	0.7223030210005464	(resolution:0.6)
# Optimized ARI-leiden:	0.7215880661122963	(resolution:0.5)
# Optimized ARI-kmeans:	0.5197838113537158	(clusters:13)
# ====================
# pca_comps:	 35
# Optimized ARI-louvain:	0.7301428156814476	(resolution:0.7)
# Optimized ARI-leiden:	0.7140427847403317	(resolution:0.5)
# Optimized ARI-kmeans:	0.47970742207924827	(clusters:10)
# ====================
# pca_comps:	 36
# Optimized ARI-louvain:	0.710569061270137	(resolution:0.5)
# Optimized ARI-leiden:	0.7145615631163574	(resolution:0.5)
# Optimized ARI-kmeans:	0.5193695220258321	(clusters:13)
# ====================
# pca_comps:	 37
# Optimized ARI-louvain:	0.7182324291320131	(resolution:0.6)
# Optimized ARI-leiden:	0.7162828588831923	(resolution:0.5)
# Optimized ARI-kmeans:	0.5162114818717234	(clusters:11)
# ====================
# pca_comps:	 38
# Optimized ARI-louvain:	0.7219168659237826	(resolution:0.7)
# Optimized ARI-leiden:	0.7195514575243273	(resolution:0.7)
# Optimized ARI-kmeans:	0.5168272028981414	(clusters:11)
# ====================
# pca_comps:	 39
# Optimized ARI-louvain:	0.7015640607083888	(resolution:0.6)
# Optimized ARI-leiden:	0.7169624064650753	(resolution:0.6)
# Optimized ARI-kmeans:	0.5167708992967865	(clusters:11)
# ====================
# pca_comps:	 40
# Optimized ARI-louvain:	0.7098511814778237	(resolution:0.6)
# Optimized ARI-leiden:	0.71691093549302	(resolution:0.6)
# Optimized ARI-kmeans:	0.47905033483501247	(clusters:10)
# ====================
# pca_comps:	 41
# Optimized ARI-louvain:	0.7049733192908253	(resolution:1.0)
# Optimized ARI-leiden:	0.7123769373865102	(resolution:0.7)
# Optimized ARI-kmeans:	0.4995074396987264	(clusters:11)
# ====================
# pca_comps:	 42
# Optimized ARI-louvain:	0.7054410917703039	(resolution:1.0)
# Optimized ARI-leiden:	0.7057825262800087	(resolution:0.5)
# Optimized ARI-kmeans:	0.5227151221183435	(clusters:12)
# ====================
# pca_comps:	 43
# Optimized ARI-louvain:	0.6846522234826719	(resolution:1.0)
# Optimized ARI-leiden:	0.708995181706306	(resolution:0.6)
# Optimized ARI-kmeans:	0.5227182493155483	(clusters:12)
# ====================
# pca_comps:	 44
# Optimized ARI-louvain:	0.7057377677402632	(resolution:0.7)
# Optimized ARI-leiden:	0.6945854668207291	(resolution:0.9)
# Optimized ARI-kmeans:	0.5140500708964294	(clusters:13)
# ====================
# pca_comps:	 45
# Optimized ARI-louvain:	0.6988816401347862	(resolution:0.7)
# Optimized ARI-leiden:	0.7035150410950894	(resolution:0.6)
# Optimized ARI-kmeans:	0.5129234948287374	(clusters:12)
# ====================
# pca_comps:	 46
# Optimized ARI-louvain:	0.6995928926911217	(resolution:0.7)
# Optimized ARI-leiden:	0.6918015215847021	(resolution:0.5)
# Optimized ARI-kmeans:	0.5175928894202995	(clusters:12)
# ====================
# pca_comps:	 47
# Optimized ARI-louvain:	0.6960509086247603	(resolution:1.0)
# Optimized ARI-leiden:	0.7059272847955234	(resolution:0.7)
# Optimized ARI-kmeans:	0.49095732527215735	(clusters:11)
# ====================
# pca_comps:	 48
# Optimized ARI-louvain:	0.680689487376245	(resolution:0.9)
# Optimized ARI-leiden:	0.7049472964334341	(resolution:0.7)
# Optimized ARI-kmeans:	0.5001475581131394	(clusters:11)
# ====================
# pca_comps:	 49
# Optimized ARI-louvain:	0.6940305000715659	(resolution:1.0)
# Optimized ARI-leiden:	0.6985071294227088	(resolution:0.6)
# Optimized ARI-kmeans:	0.5229752029007932	(clusters:12)
# ====================
# pca_comps:	 50
# Optimized ARI-louvain:	0.6850195795302685	(resolution:0.8)
# Optimized ARI-leiden:	0.7043640164299723	(resolution:0.7)
# Optimized ARI-kmeans:	0.5283409938752829	(clusters:14)
# ====================
# <><><><><><><><><><><><><><><><><><><><>
# "Best" Optimized ARI-louvain:	0.7460255003681354	n_comps:13	res:0.2
# "Best" Optimized ARI-leiden:	0.7496404761136464	n_comps:16	res:0.3
# "Best" Optimized ARI-kmeans:	0.5418780011583396	n_comps:20	k cluster:13
# <><><><><><><><><><><><><><><><><><><><>
#  TqdmWarning:/home/stud2/.conda/envs/datenanalyse/lib/python3.10/site-packages/tqdm/auto.py:21: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, figsize=(8, 8))
fig.tight_layout(pad=4.0)
fig.suptitle("Method 1: Full PCAs, no subsetting", fontsize=16, y= 1)

ax1.plot(op_louvain_ari_dict.keys(), op_louvain_ari_dict.values())
ax1.set_title('Louvain')
ax1.set_xlabel('PCA_components')
ax1.set_ylabel('ARI / Res')
ax1.legend(["Best Resolution", "Highest ARI-Score"])

ax2.plot(op_leiden_ari_dict.keys(), op_leiden_ari_dict.values())
ax2.set_title('Leiden')
ax2.set_xlabel('PCA_components')
ax2.set_ylabel('ARI / Res')
ax2.legend(["Best Resolution", "Highest ARI-Score"])

ax3.plot(op_kmeans_ari_dict.keys(), op_kmeans_ari_dict.values())
ax3.set_title('kmeans')
ax3.set_xlabel('PCA_components')
ax3.set_ylabel('K-cluster / Res')
ax3.legend(["K-cluster", "Highest ARI-Score"])

plt.show()

# %%
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(op_kmeans_ari_dict.keys(), [tup[0] for tup in op_kmeans_ari_dict.values()], 'g-')
ax2.plot(op_kmeans_ari_dict.keys(), [tup[1] for tup in op_kmeans_ari_dict.values()], 'b-')
ax2.set_ylim([0, 1])

ax1.set_xlabel('PCA_Components')
ax1.set_ylabel('K-cluster', color='g')
ax2.set_ylabel('ARI-Score', color='b')

plt.show()

# %% [markdown]
# ## 8. Best Clustering so far

# %% [markdown]
# ### 1. Louvain

# %%
# Performe a PCA
sc.pp.pca(adata, n_comps= max_op_louvain_ncomp, use_highly_variable=False) # svd_solver="lobpcg"

# Compute the neighborhood using UMAP
sc.pp.neighbors(adata, n_neighbors=n_neighbors, method=neighbor_method, metric=neighbor_metric)

# UMAP embedding
sc.tl.umap(adata, spread=umap_spread, min_dist=umap_min_dist)

# Performe the clustering
louvain_resolution = max_op_louvain_res
louvain_r_tag = f'louvain-R:{louvain_resolution}'
sc.tl.louvain(adata, resolution=louvain_resolution, key_added=louvain_r_tag)

# %% [markdown]
# ### 2. Leiden

# %%
# Performe a PCA
sc.pp.pca(adata, n_comps= max_op_leiden_ncomp, use_highly_variable=False) # svd_solver="lobpcg"

# Compute the neighborhood using UMAP
sc.pp.neighbors(adata, n_neighbors=n_neighbors, method=neighbor_method, metric=neighbor_metric)

# UMAP embedding
sc.tl.umap(adata, spread=umap_spread, min_dist=umap_min_dist)

# Performe the clustering
leiden_resolution = max_op_leiden_res
leiden_r_tag = f'leiden-R:{leiden_resolution}'
sc.tl.leiden(adata, resolution=leiden_resolution, key_added=leiden_r_tag)

# %% [markdown]
# ### 3. kmeans

# %%
# Performe a PCA
sc.pp.pca(adata, n_comps= max_op_kmeans_ncomp, use_highly_variable=False) # svd_solver="lobpcg"

# Compute the neighborhood using UMAP
sc.pp.neighbors(adata, n_neighbors=n_neighbors, method=neighbor_method, metric=neighbor_metric)

# UMAP embedding
sc.tl.umap(adata, spread=umap_spread, min_dist=umap_min_dist)

# Performes a basic kmeans clustering
epi.tl.kmeans(adata, num_clusters= max_op_kmeans_kclust)

# %% [markdown]
# ### 4. Plotting

# %%
adata.obs
# Out:
#                                      cell type  \
# 16     Smooth Muscle (Esophageal Muscularis) 1
# 17     Smooth Muscle (Esophageal Muscularis) 1
# 18     Smooth Muscle (Esophageal Muscularis) 1
# 19     Smooth Muscle (Esophageal Muscularis) 1
# 20     Smooth Muscle (Esophageal Muscularis) 1
# ...                                        ...
# 25938                     Pericyte (General) 2
# 25939                     Pericyte (General) 2
# 25940                     Pericyte (General) 2
# 25941                     Pericyte (General) 2
# 25942             Endothelial Cell (General) 3
#
#                             ontology label ontology id  n_genes_by_counts  \
# 16     smooth muscle cell of the esophagus  CL:0002599               2410
# 17     smooth muscle cell of the esophagus  CL:0002599               4710
# 18     smooth muscle cell of the esophagus  CL:0002599               2866
# 19     smooth muscle cell of the esophagus  CL:0002599               8464
# 20     smooth muscle cell of the esophagus  CL:0002599               8500
# ...                                    ...         ...                ...
# 25938                        pericyte cell  CL:0000669               1585
# 25939                        pericyte cell  CL:0000669               1807
# 25940                        pericyte cell  CL:0000669               3242
# 25941                        pericyte cell  CL:0000669               1867
# 25942                     endothelial cell  CL:0000115                720
#
#        log1p_n_genes_by_counts  total_counts  log1p_total_counts leiden-R:0.2  \
# 16                    7.787797        3953.0            8.282483            2
# 17                    8.457655        7891.0            8.973605            2
# 18                    7.961021        4669.0            8.448915            2
# 19                    9.043695       14382.0            9.573802            2
# 20                    9.047939       14767.0            9.600218            2
# ...                        ...           ...                 ...          ...
# 25938                 7.368970        2604.0            7.865188            9
# 25939                 7.499977        2991.0            8.003697            9
# 25940                 8.084254        5248.0            8.565793            9
# 25941                 7.532624        3078.0            8.032360            9
# 25942                 6.580639        1192.0            7.084227            6
#
#       leiden-R:0.3 kmeans louvain-R:0.2
# 16               3      6             3
# 17               3      6             3
# 18               3     12             3
# 19               3      6             3
# 20               3      6             3
# ...            ...    ...           ...
# 25938            8      3             9
# 25939            8      3             9
# 25940            8      3             9
# 25941            8      8             9
# 25942            6      4             6
#
# [24974 rows x 11 columns]

# %%
sc.pl.embedding(adata, basis='umap', ncols=3, show=False, color=[louvain_r_tag, leiden_r_tag, 'kmeans', 'ontology label'], wspace=0.2)
# Out:
#  UserWarning:/home/stud2/.conda/envs/datenanalyse/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#  UserWarning:/home/stud2/.conda/envs/datenanalyse/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#  UserWarning:/home/stud2/.conda/envs/datenanalyse/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#  UserWarning:/home/stud2/.conda/envs/datenanalyse/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# [<Axes: title={'center': 'louvain-R:0.2'}, xlabel='UMAP1', ylabel='UMAP2'>,
#  <Axes: title={'center': 'leiden-R:0.3'}, xlabel='UMAP1', ylabel='UMAP2'>,
#  <Axes: title={'center': 'kmeans'}, xlabel='UMAP1', ylabel='UMAP2'>,
#  <Axes: title={'center': 'ontology label'}, xlabel='UMAP1', ylabel='UMAP2'>]

# %%
sc.pl.embedding(adata, basis='umap', ncols=3, show=False, color=['cell type'], wspace=0.5)
# Out:
#  UserWarning:/home/stud2/.conda/envs/datenanalyse/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <Axes: title={'center': 'cell type'}, xlabel='UMAP1', ylabel='UMAP2'>

# %%
sc.pl.embedding(adata, basis='umap', ncols=3, show=False, color=['ontology label'], wspace=0.5)
# Out:
#  UserWarning:/home/stud2/.conda/envs/datenanalyse/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <Axes: title={'center': 'ontology label'}, xlabel='UMAP1', ylabel='UMAP2'>
