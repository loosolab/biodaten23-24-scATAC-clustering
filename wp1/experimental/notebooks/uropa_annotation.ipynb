# %%
import os.path

import episcanpy as epi
import scanpy as sc
import numpy as np
import anndata as ad
import pandas as pd
from scipy.sparse import issparse, csr_matrix, hstack
import tempfile

# %load_ext autoreload
# %autoreload 2

import utils

# %%
h5ad_path = "/mnt/workspace_stud/mbentse/catlas_objects/esophagus_muscularis_SM-A8CPH.h5ad"

data_folder = "/mnt/workspace_stud/allstud/wp1/data"
out_file = f"{data_folder}/uropa_annotation.h5ad"
out_file_by_gene = f"{data_folder}/uropa_annotation_by_gene.h5ad"

metadata_url = "http://catlas.org/catlas_downloads/humantissues/Cell_metadata.tsv.gz"
metadata_filename = "Cell_metadata.tsv"
metadata_path = f"{data_folder}/catlas_metadata/{metadata_filename}"

gtf_url="https://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_38/gencode.v38.annotation.gtf.gz"
gtf_filename="gencode.v38.annotation.gtf"
gtf_path=f"{data_folder}/{gtf_filename}"


uropa_path = "/home/stud1/.conda/envs/datenanalyse/bin/uropa"
tmpdirobj = tempfile.TemporaryDirectory()
tmpdir = tmpdirobj.name
bed_path = f"{tmpdir}/esophagus_muscularis_SM-A8CPH.bed"
uropa_config = f"{tmpdir}/config.json"
uropa_output = f"{tmpdir}/esophagus_muscularis_SM-A8CPH_finalhits.txt"

# %%
adata = epi.read_h5ad(h5ad_path)

# %%
sc.pp.calculate_qc_metrics(adata=adata, percent_top=None, inplace=True)

# %%
utils.download(metadata_path, metadata_url)
# Out:
# /mnt/workspace_stud/allstud/wp1/data/catlas_metadata/Cell_metadata.tsv already exists.

# %%
utils.load_metadata(adata, metadata_path, columns_to_keep=['cell type'])

# %%
adata.obs
# Out:
#                                                     n_genes_by_counts  \
# esophagus_muscularis_SM-A8CPH_1+AAGCTATACCGCTTC...               6264
# esophagus_muscularis_SM-A8CPH_1+AATTCGGATGAAATG...                827
# esophagus_muscularis_SM-A8CPH_1+ACTGCACAGAGTCCA...               2334
# esophagus_muscularis_SM-A8CPH_1+AGGTCACTGAGCTTA...                768
# esophagus_muscularis_SM-A8CPH_1+AGTCGGAACGCCCAA...               2940
# ...                                                               ...
# esophagus_muscularis_SM-A8CPH_1+CCATCTGGCATGCGA...               1612
# esophagus_muscularis_SM-A8CPH_1+TTATGGATGCAAAGG...                539
# esophagus_muscularis_SM-A8CPH_1+ACGTGTTGGTGAGTG...               1005
# esophagus_muscularis_SM-A8CPH_1+GGCACGAACAATACT...               1209
# esophagus_muscularis_SM-A8CPH_1+GGCACGAACAGTGTC...               1557
#
#                                                     log1p_n_genes_by_counts  \
# esophagus_muscularis_SM-A8CPH_1+AAGCTATACCGCTTC...                 8.742734
# esophagus_muscularis_SM-A8CPH_1+AATTCGGATGAAATG...                 6.719013
# esophagus_muscularis_SM-A8CPH_1+ACTGCACAGAGTCCA...                 7.755767
# esophagus_muscularis_SM-A8CPH_1+AGGTCACTGAGCTTA...                 6.645091
# esophagus_muscularis_SM-A8CPH_1+AGTCGGAACGCCCAA...                 7.986505
# ...                                                                     ...
# esophagus_muscularis_SM-A8CPH_1+CCATCTGGCATGCGA...                 7.385851
# esophagus_muscularis_SM-A8CPH_1+TTATGGATGCAAAGG...                 6.291569
# esophagus_muscularis_SM-A8CPH_1+ACGTGTTGGTGAGTG...                 6.913737
# esophagus_muscularis_SM-A8CPH_1+GGCACGAACAATACT...                 7.098376
# esophagus_muscularis_SM-A8CPH_1+GGCACGAACAGTGTC...                 7.351158
#
#                                                     total_counts  \
# esophagus_muscularis_SM-A8CPH_1+AAGCTATACCGCTTC...       10835.0
# esophagus_muscularis_SM-A8CPH_1+AATTCGGATGAAATG...        1365.0
# esophagus_muscularis_SM-A8CPH_1+ACTGCACAGAGTCCA...        4000.0
# esophagus_muscularis_SM-A8CPH_1+AGGTCACTGAGCTTA...        1181.0
# esophagus_muscularis_SM-A8CPH_1+AGTCGGAACGCCCAA...        4891.0
# ...                                                          ...
# esophagus_muscularis_SM-A8CPH_1+CCATCTGGCATGCGA...        2685.0
# esophagus_muscularis_SM-A8CPH_1+TTATGGATGCAAAGG...         888.0
# esophagus_muscularis_SM-A8CPH_1+ACGTGTTGGTGAGTG...        1593.0
# esophagus_muscularis_SM-A8CPH_1+GGCACGAACAATACT...        1920.0
# esophagus_muscularis_SM-A8CPH_1+GGCACGAACAGTGTC...        2411.0
#
#                                                     log1p_total_counts  \
# esophagus_muscularis_SM-A8CPH_1+AAGCTATACCGCTTC...            9.290629
# esophagus_muscularis_SM-A8CPH_1+AATTCGGATGAAATG...            7.219642
# esophagus_muscularis_SM-A8CPH_1+ACTGCACAGAGTCCA...            8.294300
# esophagus_muscularis_SM-A8CPH_1+AGGTCACTGAGCTTA...            7.074963
# esophagus_muscularis_SM-A8CPH_1+AGTCGGAACGCCCAA...            8.495357
# ...                                                                ...
# esophagus_muscularis_SM-A8CPH_1+CCATCTGGCATGCGA...            7.895808
# esophagus_muscularis_SM-A8CPH_1+TTATGGATGCAAAGG...            6.790097
# esophagus_muscularis_SM-A8CPH_1+ACGTGTTGGTGAGTG...            7.374002
# esophagus_muscularis_SM-A8CPH_1+GGCACGAACAATACT...            7.560601
# esophagus_muscularis_SM-A8CPH_1+GGCACGAACAGTGTC...            7.788211
#
#                                                                         cell type
# esophagus_muscularis_SM-A8CPH_1+AAGCTATACCGCTTC...                   Naive T cell
# esophagus_muscularis_SM-A8CPH_1+AATTCGGATGAAATG...                   Naive T cell
# esophagus_muscularis_SM-A8CPH_1+ACTGCACAGAGTCCA...                   Naive T cell
# esophagus_muscularis_SM-A8CPH_1+AGGTCACTGAGCTTA...                   Naive T cell
# esophagus_muscularis_SM-A8CPH_1+AGTCGGAACGCCCAA...                   Naive T cell
# ...                                                                           ...
# esophagus_muscularis_SM-A8CPH_1+CCATCTGGCATGCGA...  Fibroblast (Gastrointestinal)
# esophagus_muscularis_SM-A8CPH_1+TTATGGATGCAAAGG...  Fibroblast (Gastrointestinal)
# esophagus_muscularis_SM-A8CPH_1+ACGTGTTGGTGAGTG...        Smooth Muscle (Colon) 1
# esophagus_muscularis_SM-A8CPH_1+GGCACGAACAATACT...        Smooth Muscle (Colon) 1
# esophagus_muscularis_SM-A8CPH_1+GGCACGAACAGTGTC...        Smooth Muscle (Colon) 1
#
# [10997 rows x 5 columns]

# %%
utils.download(gtf_path, gtf_url)
# Out:
# /mnt/workspace_stud/allstud/wp1/data/gencode.v38.annotation.gtf already exists.

# %%
def parse_region(region):
    if ':' in region and '-' in region:
        chrom, positions = region.split(':')
        begin, end = map(int, positions.split('-'))
    elif '_' in region:
        chrom, begin, end = region.split('_')
        begin, end = int(begin), int(end)
    else:
        raise ValueError(f"Invalid region format: {region}")
    return chrom, begin, end

with open(bed_path, "w") as f:
    for region in adata.var_names.tolist():
        chrom, begin, end = parse_region(region)
        f.write(f"{chrom}\t{begin}\t{end}\n")
    f.flush()

# %%
# %%bash -s {tmpdir} {uropa_config} {gtf_path} {bed_path}
# cat >$2 << EOF
# {
# "queries":[
#     {
#         "distance": [5000, 2000],
#         "feature": ["gene"],
#         "feature_anchor": ["end", "start", "center"]
#     }
# ],
# "show_attributes": ["gene_name"],
# "priority": "False",
# "gtf": "$3",
# "bed": "$4",
# "outdir": "$1",
# "threads": "$(nproc --all)"
# }
# EOF

# %%
# %%time
# !{uropa_path} -i {uropa_config}
# Out:
# 2023-12-11 22:19:02 (413156) [INFO]	Started UROPA 4.0.3
# 2023-12-11 22:19:02 (413156) [INFO]	Working directory: /home/stud1/notebooks
# 2023-12-11 22:19:02 (413156) [INFO]	Command-line call: /home/stud1/.conda/envs/datenanalyse/bin/uropa -i /tmp/tmpdf1jtvnx/config.json
# 2023-12-11 22:19:02 (413156) [INFO]	Reading configuration from commandline/input config
# 2023-12-11 22:19:02 (413156) [INFO]	Preparing .gtf-file for fast access
# 2023-12-11 22:19:37 (413156) [INFO]	Started annotation
# 2023-12-11 22:19:42 (413156) [INFO]	Progress: Annotated 35000 peaks (0 jobs running; 35 jobs finished)
# 2023-12-11 22:19:48 (413156) [INFO]	Progress: Annotated 85000 peaks (0 jobs running; 85 jobs finished)
# 2023-12-11 22:19:53 (413156) [INFO]	Progress: Annotated 135000 peaks (0 jobs running; 135 jobs finished)
# 2023-12-11 22:19:58 (413156) [INFO]	Progress: Annotated 185000 peaks (0 jobs running; 185 jobs finished)
# 2023-12-11 22:20:03 (413156) [INFO]	Progress: Annotated 235000 peaks (0 jobs running; 235 jobs finished)
# 2023-12-11 22:20:08 (413156) [INFO]	Progress: Annotated 285000 peaks (0 jobs running; 285 jobs finished)
# 2023-12-11 22:20:14 (413156) [INFO]	Progress: Annotated 335000 peaks (0 jobs running; 335 jobs finished)
# 2023-12-11 22:20:19 (413156) [INFO]	Progress: Annotated 385000 peaks (0 jobs running; 385 jobs finished)
# 2023-12-11 22:20:24 (413156) [INFO]	Progress: Annotated 435000 peaks (0 jobs running; 435 jobs finished)
# 2023-12-11 22:20:29 (413156) [INFO]	Progress: Annotated 485000 peaks (0 jobs running; 485 jobs finished)
# 2023-12-11 22:20:34 (413156) [INFO]	Progress: Annotated 535000 peaks (0 jobs running; 535 jobs finished)
# 2023-12-11 22:20:39 (413156) [INFO]	Progress: Annotated 585000 peaks (0 jobs running; 585 jobs finished)
# 2023-12-11 22:20:45 (413156) [INFO]	Progress: Annotated 635000 peaks (0 jobs running; 635 jobs finished)
# 2023-12-11 22:20:50 (413156) [INFO]	Progress: Annotated 685000 peaks (0 jobs running; 685 jobs finished)
# 2023-12-11 22:20:55 (413156) [INFO]	Progress: Annotated 735000 peaks (0 jobs running; 735 jobs finished)
# 2023-12-11 22:21:00 (413156) [INFO]	Progress: Annotated 785000 peaks (0 jobs running; 785 jobs finished)
# 2023-12-11 22:21:05 (413156) [INFO]	Progress: Annotated 835000 peaks (0 jobs running; 835 jobs finished)
# 2023-12-11 22:21:10 (413156) [INFO]	Progress: Annotated 885000 peaks (0 jobs running; 885 jobs finished)
# 2023-12-11 22:21:16 (413156) [INFO]	Progress: Annotated 935000 peaks (0 jobs running; 935 jobs finished)
# 2023-12-11 22:21:21 (413156) [INFO]	Progress: Annotated 985000 peaks (0 jobs running; 985 jobs finished)
# 2023-12-11 22:21:26 (413156) [INFO]	Progress: Annotated 1035000 peaks (0 jobs running; 1035 jobs finished)
# 2023-12-11 22:21:31 (413156) [INFO]	Progress: Annotated 1085000 peaks (0 jobs running; 1085 jobs finished)
# 2023-12-11 22:21:36 (413156) [INFO]	Progress: Annotated 1135000 peaks (0 jobs running; 1135 jobs finished)
# 2023-12-11 22:21:38 (413156) [INFO]	The input .bed-file has been read and all jobs have been started. Waiting for the final tasks to finish...
# 2023-12-11 22:21:38 (413156) [INFO]	Processing annotated peaks
# 2023-12-11 22:21:38 (413156) [INFO]	Cleaning up temporary files
# 2023-12-11 22:21:38 (413156) [INFO]	UROPA run finished in 0:02:36!
# CPU times: user 1.15 s, sys: 282 ms, total: 1.44 s
# Wall time: 2min 37s

# %%
uropa_df = pd.read_csv(uropa_output, delimiter="\t")
uropa_df['index'] = uropa_df['peak_chr'].astype(str) + ':' + uropa_df['peak_start'].astype(str) + '-' + uropa_df['peak_end'].astype(str)
uropa_df = uropa_df[['index', 'gene_name']]
uropa_df = uropa_df.set_index('index')
adata.var = adata.var.merge(uropa_df, left_index=True, right_index=True)

# %%
tmpdirobj.cleanup()

# %%
adata.var
# Out:
#                         n_cells_by_counts  mean_counts  log1p_mean_counts  \
# index
# chr1:9955-10355                       226     0.037738           0.037043
# chr1:29163-29563                        3     0.000364           0.000364
# chr1:79215-79615                        0     0.000000           0.000000
# chr1:102755-103155                      0     0.000000           0.000000
# chr1:180580-180980                    182     0.032827           0.032300
# ...                                   ...          ...                ...
# chrY:56676947-56677347                  0     0.000000           0.000000
# chrY:56677442-56677842                  4     0.000364           0.000364
# chrY:56678029-56678429                 11     0.001000           0.001000
# chrY:56678600-56679000                  0     0.000000           0.000000
# chrY:56707025-56707425                 20     0.003092           0.003087
#
#                         pct_dropout_by_counts  total_counts  \
# index
# chr1:9955-10355                     97.944894         415.0
# chr1:29163-29563                    99.972720           4.0
# chr1:79215-79615                   100.000000           0.0
# chr1:102755-103155                 100.000000           0.0
# chr1:180580-180980                  98.345003         361.0
# ...                                       ...           ...
# chrY:56676947-56677347             100.000000           0.0
# chrY:56677442-56677842              99.963626           4.0
# chrY:56678029-56678429              99.899973          11.0
# chrY:56678600-56679000             100.000000           0.0
# chrY:56707025-56707425              99.818132          34.0
#
#                         log1p_total_counts    gene_name
# index
# chr1:9955-10355                   6.030685      DDX11L1
# chr1:29163-29563                  1.609438  MIR1302-2HG
# chr1:79215-79615                  0.000000          NaN
# chr1:102755-103155                0.000000          NaN
# chr1:180580-180980                5.891644     DDX11L17
# ...                                    ...          ...
# chrY:56676947-56677347            0.000000          NaN
# chrY:56677442-56677842            1.609438          NaN
# chrY:56678029-56678429            2.484907          NaN
# chrY:56678600-56679000            0.000000          NaN
# chrY:56707025-56707425            3.555348          NaN
#
# [1154611 rows x 7 columns]

# %%
adata.raw = adata
epi.pp.binarize(adata)

# %%
epi.pp.coverage_cells(adata, binary=True, log=False, bins=50,
               threshold=100)
epi.pp.coverage_cells(adata, binary=True, log=10, bins=50,
               threshold=100)

epi.pp.cal_var(adata)
# Out:
#  UserWarning:/home/stud1/.conda/envs/datenanalyse/lib/python3.10/site-packages/episcanpy/preprocessing/_quality_control.py:58:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#  FutureWarning:/home/stud1/.conda/envs/datenanalyse/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#  FutureWarning:/home/stud1/.conda/envs/datenanalyse/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#  UserWarning:/home/stud1/.conda/envs/datenanalyse/lib/python3.10/site-packages/episcanpy/preprocessing/_quality_control.py:60:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#  FutureWarning:/home/stud1/.conda/envs/datenanalyse/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#  FutureWarning:/home/stud1/.conda/envs/datenanalyse/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %%
epi.pp.filter_cells(adata, min_features=100)
epi.pp.filter_cells(adata, max_features=10000)

# %%
sc.pp.normalize_total(adata, exclude_highly_expressed=False, target_sum=None)
epi.pp.log1p(adata)

# %%
# %%time
sc.pp.pca(adata, n_comps=50, use_highly_variable=False)
# Out:
# CPU times: user 5min 14s, sys: 9min 29s, total: 14min 44s
# Wall time: 3min 55s

# %%
sc.pl.pca_overview(adata, color="log1p_n_genes_by_counts")

# %%
start = 1
n_pcs = 20
adata.obsm["X_pca"] = adata.obsm["X_pca"][:, start:n_pcs]
adata.varm["PCs"] = adata.varm["PCs"][:, start:n_pcs]

if "variance_ratio" in adata.uns.get("pca", {}):
    adata.uns["pca"]["variance_ratio"] = adata.uns["pca"]["variance_ratio"][start:n_pcs]

# %%
# %%time
sc.pp.neighbors(adata, n_neighbors=15, method='umap', metric='euclidean')
# Out:
# CPU times: user 24.1 s, sys: 1.04 s, total: 25.2 s
# Wall time: 23.4 s

# %%
# %%time
sc.tl.umap(adata, min_dist=0.1, spread=2.5)
# Out:
# CPU times: user 8.99 s, sys: 1.19 s, total: 10.2 s
# Wall time: 8.73 s

# %%
sc.pl.embedding(adata, basis='umap', ncols=3, show=False, color="log1p_n_genes_by_counts")
# Out:
# <Axes: title={'center': 'log1p_n_genes_by_counts'}, xlabel='UMAP1', ylabel='UMAP2'>

# %%
sc.tl.louvain(adata, resolution=0.6)

# %%
sc.pl.embedding(adata, basis='umap', ncols=3, show=False, color="louvain")
# Out:
#  FutureWarning:/home/stud1/.conda/envs/datenanalyse/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1251: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#  UserWarning:/home/stud1/.conda/envs/datenanalyse/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <Axes: title={'center': 'louvain'}, xlabel='UMAP1', ylabel='UMAP2'>

# %%
sc.pl.embedding(adata, basis='umap', ncols=3, show=False, color="cell type")
# Out:
#  FutureWarning:/home/stud1/.conda/envs/datenanalyse/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1251: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#  UserWarning:/home/stud1/.conda/envs/datenanalyse/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <Axes: title={'center': 'cell type'}, xlabel='UMAP1', ylabel='UMAP2'>

# %%
# %%time
adata.write(
        out_file,
        compression="gzip")
# Out:
# CPU times: user 26.1 s, sys: 670 ms, total: 26.8 s
# Wall time: 27.2 s

# %%
adata = adata[:, ~adata.var['gene_name'].isna()]

# %%
duplicated_genes = adata.var['gene_name'][adata.var['gene_name'].duplicated(keep=False)]

# %%
# %%time
adata_csc = adata.X.tocsc()
# Out:
# CPU times: user 928 ms, sys: 160 ms, total: 1.09 s
# Wall time: 1.09 s

# %%
# %%time
merged_data_dict = {}
for gene in duplicated_genes.unique():
    cols = np.where(adata.var['gene_name'] == gene)[0]
    data_slice = adata_csc[:, cols]
    merged = data_slice.max(axis=1)
    merged_data_dict[gene] = merged
# Out:
# CPU times: user 37.9 s, sys: 150 ms, total: 38.1 s
# Wall time: 38.1 s

# %%
# %%time
non_duplicated_genes = adata.var['gene_name'][~adata.var['gene_name'].duplicated(keep=False)]
for gene in non_duplicated_genes:
    cols = np.where(adata.var['gene_name'] == gene)[0]
    data_slice = adata_csc[:, cols]
    merged_data_dict[gene] = data_slice
# Out:
# CPU times: user 2.85 s, sys: 9.23 ms, total: 2.86 s
# Wall time: 2.86 s

# %%
merged_matrix = hstack([l for l in merged_data_dict.values()], format='csr')

# %%
adata_merged = ad.AnnData(X=merged_matrix, obs=adata.obs, obsm=adata.obsm, var=pd.DataFrame(index=merged_data_dict.keys()))

# %%
# %%time
adata_merged.write(
        out_file_by_gene,
        compression="gzip")
# Out:
# CPU times: user 3.55 s, sys: 70.9 ms, total: 3.62 s
# Wall time: 3.66 s

# %%
adata_merged
# Out:
# AnnData object with n_obs × n_vars = 10910 × 52277
#     obs: 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'cell type', 'nb_features', 'louvain'
#     obsm: 'X_pca', 'X_umap'
